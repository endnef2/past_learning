# %% [markdown]
# # 모두의 데이터분석 with 파이썬
# ## Unit 7 ~ 9

# %% [markdown]
# ## Unit 07. 우리 동네 인구 구조 시각화하기

# %%
# 인구 데이터 파일(2021.2 / 0세 ~ 100세)
# 전체 데이터에서 한 줄씩 반복해서 읽어온다
import csv
f = open('age.csv')
data = csv.reader(f)
header = next(data)
    
f.close()

# %%
# 우리 동네에 대한 데이터인지 확인한다
# 우리 동네일 경우 0세부터 100세 이상까지의 인구수를 순서대로 저장한다.
import csv
f = open('age.csv')
data = csv.reader(f)
header = next(data)
result = []
for row in data:
    if '금정동' in row[0]:
        for i in row[3:] :
            result.append(int(i))
print(result)
print(len(result))
# Out:
# [59, 72, 74, 79, 98, 97, 81, 89, 109, 104, 104, 108, 111, 120, 95, 103, 106, 123, 119, 174, 196, 230, 244, 245, 270, 277, 334, 307, 323, 337, 252, 288, 232, 215, 221, 193, 221, 220, 260, 239, 232, 244, 228, 236, 267, 234, 216, 282, 265, 311, 330, 337, 331, 326, 365, 334, 350, 326, 385, 410, 410, 330, 305, 304, 309, 271, 263, 178, 193, 161, 145, 146, 127, 125, 119, 83, 98, 78, 107, 86, 59, 70, 59, 56, 40, 47, 27, 24, 33, 18, 21, 10, 10, 9, 2, 3, 3, 1, 4, 3, 9]
# 101

# %%
# 저장된 연령별 인구수 데이터를 시각화한다.
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(result)
plt.show()

# %%
# 다앙한 스타일의 이름확인가능
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn')
plt.plot(result)
plt.show()

# %%
# 아름동의 인구구조 시각화 결과를 얻어라!
import csv
f = open('age.csv')
data = csv.reader(f)
header = next(data)
result = []
aaa = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
for row in data:
    if aaa in row[0]:
        for i in row[3:] :
            result.append(int(i.replace(',','')))  # age.csv파일의 콤마(,)를 빈문자로 바꿔줌
            
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rc('font', family = 'Malgun Gothic')
plt.title(aaa + ' 지역의 인구 구조')
plt.plot(result)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 아름동

# %% [markdown]
# ## Unit 08. 인구 구조를 다양한 형태로 시각화하기

# %%
import csv
f = open('age.csv')
data = csv.reader(f)
header = next(data)
result = []
aaa = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
for row in data:
    if aaa in row[0]:
        for i in row[3:] :
            result.append(int(i.replace(',','')))  # age.csv파일의 콤마(,)를 빈문자로 바꿔줌
            
import matplotlib.pyplot as plt
plt.bar(range(101), result)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 신도림

# %%
import csv
f = open('age.csv')
data = csv.reader(f)
header = next(data)
result = []
aaa = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
for row in data:
    if aaa in row[0]:
        for i in row[3:] :
            result.append(int(i.replace(',','')))  # age.csv파일의 콤마(,)를 빈문자로 바꿔줌
            
import matplotlib.pyplot as plt
plt.bar(range(101), result)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 신도림

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
m = []
f = []
for row in data:
    if '신도림' in row[0]:
        for i in range(0, 101) :
            m.append(int(row[i+3]))
            f.append(int(row[-(i+1)]))
            
f.reverse()

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
m = []
f = []

for row in data :
    if '금정동' in row[0]:
        for i in row[3:104] :
            m.append(-int(i.replace(',','')))
        for i in row[106:]:
            f.append(int(i.replace(',','')))

# %%
import matplotlib.pyplot as plt
plt.barh(range(101), m)
plt.barh(range(101), f)
plt.show()

# %%
# 마이너스 부호를 넣어 음수로 변경 ...?
m.append(-int(i))
print(m)
# Out:
# [33, 34, 43, 46, 49, 49, 45, 44, 52, 60, 58, 55, 50, 67, 54, 44, 56, 62, 61, 101, 111, 121, 115, 115, 137, 150, 180, 166, 192, 189, 131, 183, 128, 115, 127, 118, 125, 125, 145, 122, 140, 123, 132, 117, 153, 139, 120, 143, 140, 150, 191, 175, 171, 158, 176, 178, 183, 169, 197, 202, 206, 159, 143, 157, 158, 123, 121, 88, 114, 90, 77, 82, 72, 52, 49, 43, 45, 34, 49, 32, 25, 31, 24, 22, 11, 12, 5, 9, 10, 3, 5, 1, 3, 1, 2, 0, 0, 0, 1, 1, 3, -6]

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title('금정동 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label = '남성')
plt.barh(range(101), f, laber = '여성')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-1f0ab2c512ac> in <module>
#       3 plt.rcParams['axes.unicode_minus'] = False
#       4 plt.title('금정동 지역의 남녀 성별 인구 분포')
# ----> 5 plt.barh(range(101), m, label = '남성')
#       6 plt.barh(range(101), f, laber = '여성')
#       7 plt.legend()
#
# ~\jm\lib\site-packages\matplotlib\pyplot.py in barh(y, width, height, left, align, **kwargs)
#    2500 @_copy_docstring_and_deprecators(Axes.barh)
#    2501 def barh(y, width, height=0.8, left=None, *, align='center', **kwargs):
# -> 2502     return gca().barh(
#    2503         y, width, height=height, left=left, align=align, **kwargs)
#    2504
#
# ~\jm\lib\site-packages\matplotlib\axes\_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2628         """
#    2629         kwargs.setdefault('orientation', 'horizontal')
# ...

# %%
# 항아리 모양 그래프 그리기

import csv
f = open('gender.csv') # csv파일 불러오기
data = csv.reader(f)

# 데이터를 넣을 리스트 만들기
m = []
f = []

name = input('지역의 이름을 알려주세요 : ')

for row in data:
    if name in row[0]: # in row 쓰기...
        for i in row[3:104] :
            m.append(-int(i.replace(',',''))) # m에 해당하는 데이터를 음수로 넣기( , -> 공백으로!)
        for i in row[106:] :
            f.append(int(i.replace(',',''))) # f에 해당하는 데이터 넣기

# 그래프 만들기

import matplotlib.pyplot as plt

# plt.style.use('ggplot')
# plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.title(name + ' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label = '남성')
plt.barh(range(101), f, label = '여성')
plt.legend() # 범례 표현
plt.show()
# Out:
# 지역의 이름을 알려주세요 : 금정동

# %%
# 항아리 모양 그래프 그리기

import csv
f = open('gender.csv') # csv파일 불러오기
data = csv.reader(f)

# 데이터를 넣을 리스트 만들기
m = []
f = []

name = input('지역의 이름을 알려주세요 : ')

for row in data:
    if name in row[0]: # in row 쓰기...
        for i in row[3:104] :
            m.append(-int(i.replace(',',''))) # m에 해당하는 데이터를 음수로 넣기( , -> 공백으로!)
        for i in row[106:] :
            f.append(int(i.replace(',',''))) # f에 해당하는 데이터 넣기

# 그래프 만들기

import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.title(name + ' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label = '남성')
plt.barh(range(101), f, label = '여성')
plt.legend() # 범례 표현
plt.show()
# Out:
# 지역의 이름을 알려주세요 : 금정동

# %% [markdown]
# ## Unit 09. 우리 동네 인구 구조를 파이 차트로 나타내기

# %%
import csv
f = open('gender.csv') # csv파일 불러오기
data = csv.reader(f)

# 데이터를 넣을 리스트 만들기
m = []
f = []

name = input('지역의 이름을 알려주세요 : ')

for row in data:
    if name in row[0]: # in row 쓰기...
        for i in row[3:104] :
            m.append(-int(i.replace(',',''))) # m에 해당하는 데이터를 음수로 넣기( , -> 공백으로!)
        for i in row[106:] :
            f.append(int(i.replace(',',''))) # f에 해당하는 데이터 넣기
        
        break # 반복문 실행 멈추기

# 그래프 만들기

import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.title(name + ' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label = '남성')
plt.barh(range(101), f, label = '여성')
plt.legend() # 범례 표현
plt.show()
# Out:
# 지역의 이름을 알려주세요 : 제주특별자치도

# %%
import csv
f = open('gender.csv') # csv파일 불러오기
data = csv.reader(f)

# 데이터를 넣을 리스트 만들기
m = []
f = []

name = input('지역의 이름을 알려주세요 : ')

for row in data:
    if name in row[0]: # in row 쓰기...        
        for i in row[3:104] :
            m.append(-int(i.replace(',',''))) # m에 해당하는 데이터를 음수로 넣기( , -> 공백으로!)
        for i in row[106:] :
            f.append(int(i.replace(',',''))) # f에 해당하는 데이터 넣기
        
        break # 반복문 실행 멈추기

# 그래프 만들기

import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.title(row[0] + ' ' + ' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label = '남성')
plt.barh(range(101), f, label = '여성')
plt.legend() # 범례 표현
plt.show()
# Out:
# 지역의 이름을 알려주세요 : 부흥동

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')
size = [2441, 2312, 1031, 1233]
label = ['A형', 'B형', 'AB형', 'O형']
color = ['darkmagenta', 'deeppink', 'hotpink', 'pink']
plt.axis('equal')
plt.pie(size, labels = label, autopct = '%.1f%%', colors = color, explode=(0, 0, 0.1, 0))
plt.legend()
plt.show()

# %%
import csv
f = open('gender.csv') # csv파일 불러오기
data = csv.reader(f)
size = []

name = input('지역의 이름을 알려주세요 : ')

for row in data:
    if name in row[0]: # in row 쓰기...
        m = 0
        f = 0
        for i in range(101) :
            m += int(row[i+3].replace(',','')) # 3 ~ 103번까지 데이터 더하기(, =>공백으로 바꾸기)
            f += int(row[i+106].replace(',','')) # 106 ~ 206번까지 데이터 더하기
        
        break # 반복문 실행 멈추기

size.append(m)
size.append(f)
print(size)
# Out:
# 지역의 이름을 알려주세요 : 제주특별자치도
# [338673, 336464]

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family='Malgun Gothic') # 한글 폰트
color = ['crimson', 'darkcyan'] #색 효과
plt.axis('equal') # 동그란 원 그리기
plt.pie(size, labels=['남', '여'], autopct='%.1f%%', colors=color, startangle=90) # 레이블 추가, 소수점 아래 첫번째 소수점까지 비율표현 및 범례추가
plt.title(name+' 지역의 남녀 성별 비율') # 제목 추가
plt.show()
