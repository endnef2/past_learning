# %% [markdown]
# # 모두의 데이터분석 with 파이썬
# ## Unit 10. 우리 동네 인구 구조를 산점도로 나타내기

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
m = []
f = []

name = input('궁금한 동네를 입력하세요 : ')

for row in data :
    if name in row[0]:
        for i in row[3:104] :
            m.append(int(i.replace(',','')))
        for i in row[106:]:
            f.append(int(i.replace(',','')))
        break
        
print(f)
# Out:
# 궁금한 동네를 입력하세요 : 금정동
# [26, 38, 31, 33, 49, 48, 36, 45, 57, 44, 46, 53, 61, 53, 41, 59, 50, 61, 58, 73, 85, 109, 129, 130, 133, 127, 154, 141, 131, 148, 121, 105, 104, 100, 94, 75, 96, 95, 115, 117, 92, 121, 96, 119, 114, 95, 96, 139, 125, 161, 139, 162, 160, 168, 189, 156, 167, 157, 188, 208, 204, 171, 162, 147, 151, 148, 142, 90, 79, 71, 68, 64, 55, 73, 70, 40, 53, 44, 58, 54, 34, 39, 35, 34, 29, 35, 22, 15, 23, 15, 16, 9, 7, 8, 0, 3, 3, 1, 3, 2, 6]

# %%
# 꺾은선 그래프 나타내기
import matplotlib.pyplot as plt
plt.plot(m, label='Male')
plt.plot(f, label='Female')
plt.legend()
plt.show()

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
result = []

name = input('궁금한 동네를 입력하세요 : ')

for row in data :
    if name in row[0]:
        for i in range(3, 104) :
            result.append(int(row[i]) - int(row[i+103]))
        break
# Out:
# 궁금한 동네를 입력하세요 : 금정동

# %%
import matplotlib.pyplot as plt
plt.bar(range(101), result)
plt.show()

# %%
# scatter()함수로 표현하기
import matplotlib.pyplot as plt
plt.scatter([1, 2, 3, 4], [10, 20, 30, 40])
plt.show()

# %%
# 버블차트로 표현하기
import matplotlib.pyplot as plt
plt.scatter([1, 2, 3, 4], [10, 20, 30, 40], s=[100, 200, 250, 300], c = range(4), cmap = 'jet')
plt.show()

# %%
# 제주도의 연령대별 성별 비율을 산점도로 표현하기

import csv
f = open('gender.csv')
data = csv.reader(f)
m = []
f = []
name = input('궁금한 동네를 입력해주세요! : ')

for row in data:
    if name in row[0]: # in row 쓰기...
        for i in row[3:104] :
            m.append(int(i.replace(',',''))) 
        for i in row[106:] :
            f.append(int(i.replace(',',''))) 
        
        break # 반복문 실행 멈추기
# Out:
# 궁금한 동네를 입력해주세요! : 제주특별자치도

# %%
# 버블차트로 표현하기
import matplotlib.pyplot as plt
plt.scatter(m, f)
plt.show()

# %%
# 버블차트로 표현하기
import matplotlib.pyplot as plt
plt.scatter(m, f, c=range(101), alpha=0.5, cmap='jet')
plt.colorbar()
plt.plot(range(max(m)), range(max(m)), 'g')
plt.show()

# %% [markdown]
# ## 제주도의 연령대별 성별 비율을 산점도로 표현하기 ...ERROR... csv파일...

# %%
import csv
import math
f = open('gender.csv')
data = csv.reader(f)
m = []
f = []
size = []
name = input('궁금한 동네를 입력해주세요! : ')

for row in data :
    if name in row[0] :
        for i in range(3,104) :
            m.append(int(row[i]))
            f.append(int(row[i+103]))
            size.append(math.sqrt(int(row[i])+int(row[i+103])))
        break
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rc('font',family='Malgun Gothic')
plt.figure(figsize=(10,5), dpi=300)
plt.title(name+' 지역의 성별 인구 그래프')
plt.scatter(m, f, s=size, c=range(101), alpha=0.5, cmap='jet')
plt.colorbar()
plt.plot(range(max(m)),range(max(m)), 'g')
plt.xlabel('남성 인구수')
plt.ylabel('여성 인구수')
plt.show()
# Out:
# 궁금한 동네를 입력해주세요! : 제주특별자치도
