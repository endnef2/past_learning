# %%
import csv
import matplotlib.pyplot as plt

f= open('train.csv')
data = csv.reader(f)

for row in data :
    print(row)
f.close()
# Out:
# ['inst_id', 'OC', 'sido', 'sgg', 'openDate', 'bedCount', 'instkind', 'revenue1', 'salescost1', 'sga1', 'salary1', 'noi1', 'noe1', 'interest1', 'ctax1', 'profit1', 'liquidAsset1', 'quickAsset1', 'receivableS1', 'inventoryAsset1', 'nonCAsset1', 'tanAsset1', 'OnonCAsset1', 'receivableL1', 'debt1', 'liquidLiabilities1', 'shortLoan1', 'NCLiabilities1', 'longLoan1', 'netAsset1', 'surplus1', 'revenue2', 'salescost2', 'sga2', 'salary2', 'noi2', 'noe2', 'interest2', 'ctax2', 'profit2', 'liquidAsset2', 'quickAsset2', 'receivableS2', 'inventoryAsset2', 'nonCAsset2', 'tanAsset2', 'OnonCAsset2', 'receivableL2', 'debt2', 'liquidLiabilities2', 'shortLoan2', 'NCLiabilities2', 'longLoan2', 'netAsset2', 'surplus2', 'employee1', 'employee2', 'ownerChange']
# ...

# %%
import pandas as pd  #pandas 이용
import matplotlib.pyplot as plt

data = pd.read_csv('C:/Users/Admin/pbl_ml/Trial/조별과제/train.csv') # pandas를 이용해 csv데이터 불러오기
data.shape
data
# Out:
#      inst_id      OC       sido  sgg  openDate  bedCount  \
# 0          1    open  choongnam   73  20071228     175.0
# 1          3    open  gyeongnam   32  19970401     410.0
# 2          4    open   gyeonggi   89  20161228     468.0
# 3          7    open    incheon  141  20000814     353.0
# 4          9    open  gyeongnam   32  20050901     196.0
# ..       ...     ...        ...  ...       ...       ...
# 296      422    open    jeonnam  178  20050211     214.0
# 297      423   close  choongnam  159  20140618       NaN
# 298      426   close  gyeongbuk  107  19830705       NaN
# 299      427   close   gyeonggi  169  20070101     180.0
# 300      428    open      seoul   79  20011017       NaN
#
#                  instkind      revenue1    salescost1          sga1  ...  \
# 0        nursing_hospital  4.217530e+09  0.000000e+00  3.961135e+09  ...
# 1        general_hospital           NaN           NaN           NaN  ...
# ...

# %%
import pandas as pd  #pandas 이용
import matplotlib.pyplot as plt

data = pd.read_csv('C:/Users/Admin/pbl_ml/Trial/조별과제/train.csv') # pandas를 이용해 csv데이터 불러오기
data.shape
data.head(8)
# Out:
#    inst_id    OC       sido  sgg  openDate  bedCount          instkind  \
# 0        1  open  choongnam   73  20071228     175.0  nursing_hospital
# 1        3  open  gyeongnam   32  19970401     410.0  general_hospital
# 2        4  open   gyeonggi   89  20161228     468.0  nursing_hospital
# 3        7  open    incheon  141  20000814     353.0  general_hospital
# 4        9  open  gyeongnam   32  20050901     196.0  general_hospital
# 5       11  open  gyeongnam  155  20020501     243.0  general_hospital
# 6       14  open   gyeonggi  169  19820702     213.0  general_hospital
# 7       15  open      busan   66  19871102     250.0  general_hospital
#
#        revenue1    salescost1          sga1  ...         debt2  \
# 0  4.217530e+09  0.000000e+00  3.961135e+09  ...  7.589937e+08
# 1           NaN           NaN           NaN  ...           NaN
# 2  1.004522e+09  5.154837e+08  4.472197e+08  ...  0.000000e+00
# 3  7.250734e+10  0.000000e+00  7.067740e+10  ...  3.775501e+10
# ...

# %%
data.describe()
# Out:
#           inst_id         sgg      openDate    bedCount      revenue1  \
# count  301.000000  301.000000  3.010000e+02  296.000000  2.930000e+02
# mean   219.056478   81.039867  2.005013e+07  145.709459  1.288175e+10
# std    121.234869   50.969714  8.893815e+04  118.923890  2.043543e+10
# min      1.000000    1.000000  1.978012e+07    0.000000  0.000000e+00
# 25%    112.000000   37.000000  2.001102e+07   52.750000  3.252112e+09
# 50%    230.000000   75.000000  2.007113e+07  136.500000  5.524218e+09
# 75%    321.000000  123.000000  2.011102e+07  193.000000  1.274839e+10
# max    428.000000  178.000000  2.017061e+07  656.000000  1.510000e+11
#
#          salescost1          sga1       salary1          noi1          noe1  \
# count  2.930000e+02  2.930000e+02  2.930000e+02  2.930000e+02  2.930000e+02
# mean   2.014903e+09  1.033244e+10  5.654115e+09  2.696151e+08  5.115870e+08
# std    7.460271e+09  1.493886e+10  8.083343e+09  8.023701e+08  1.060379e+09
# ...

# %%
data.boxplot(column='revenue1', return_type='dict')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22cf76ae5e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22cf76aeca0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22cf76ae280>],
#  'medians': [<matplotlib.lines.Line2D at 0x22cf76b73a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22cf76b7700>],
#  'means': []}

# %%
data.boxplot(column=('revenue1','revenue2'), by='OC')
# Out:
# array([<AxesSubplot:title={'center':'revenue1'}, xlabel='OC'>,
#        <AxesSubplot:title={'center':'revenue2'}, xlabel='OC'>],
#       dtype=object)

# %%
import seaborn    ## 참고 : https://datascienceschool.net/01%20python/05.04%20%EC%8B%9C%EB%B3%B8%EC%9D%84%20%EC%82%AC%EC%9A%A9%ED%95%9C%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%ED%8F%AC%20%EC%8B%9C%EA%B0%81%ED%99%94.html

plt.rcParams['font.family'] = 'Malgun Gothic'
sns.barplot(x="revenue1" , y="instkind", hue= "OC" , data=data )
plt.rcParams["figure.dpi"] = 300
plt.title("병원종류별, 개폐업병원의 17년도의 17년도 매출액")
plt.show()

# %%
import pandas as pd  #pandas 이용
import matplotlib.pyplot as plt

data = pd.read_csv('C:/Users/Admin/pbl_ml/Trial/조별과제/train.csv') # pandas를 이용해 csv데이터 불러오기
selectdata = pd.DataFrame(data, columns=["inst_id", "OC", "instkind", "revenue1", "Profit1", "debt1", "liquidLiabilities1", "revenue2", "profit2", "Debt2", "liquidLiabilities2"])
selectdata
# Out:
#      inst_id      OC              instkind      revenue1  Profit1  \
# 0          1    open      nursing_hospital  4.217530e+09      NaN
# 1          3    open      general_hospital           NaN      NaN
# 2          4    open      nursing_hospital  1.004522e+09      NaN
# 3          7    open      general_hospital  7.250734e+10      NaN
# 4          9    open      general_hospital  4.904354e+10      NaN
# ..       ...     ...                   ...           ...      ...
# 296      422    open      nursing_hospital  7.614697e+09      NaN
# 297      423   close              hospital  6.717144e+09      NaN
# 298      426   close              hospital  0.000000e+00      NaN
# 299      427   close      nursing_hospital  2.116892e+09      NaN
# 300      428    open  traditional_hospital  1.340971e+09      NaN
#
#             debt1  liquidLiabilities1      revenue2       profit2  Debt2  \
# 0    6.828260e+08        2.013237e+08  4.297848e+09  2.078297e+08    NaN
# ...

# %%
#pairplot 수치에 해당하는 그래프를 전반적으로 그려줌(관계 그래프 확인용)
sns.pairplot(data = selectdata)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Admin\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
