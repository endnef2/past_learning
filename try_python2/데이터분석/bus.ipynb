# %% [markdown]
# ## 버스 운행시간 예측 프로젝트
# 참고 : https://dacon.io/edu/1003

# %%
import pandas as pd

# %% [markdown]
# ### 데이터 불러오기, 확인

# %%
test = pd.read_csv('C:/Users/endne/OneDrive/바탕 화면/파이썬/알고리즘/dataset/229611_버스 운행시간 예측 경진대회_data/test.csv')
train = pd.read_csv('C:/Users/endne/OneDrive/바탕 화면/파이썬/알고리즘/dataset/229611_버스 운행시간 예측 경진대회_data/train.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210457 entries, 0 to 210456
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                210457 non-null  int64
#  1   date              210457 non-null  object
#  2   route_id          210457 non-null  int64
#  3   vh_id             210457 non-null  int64
#  4   route_nm          210457 non-null  object
#  5   now_latitude      210457 non-null  float64
#  6   now_longitude     210457 non-null  float64
#  7   now_station       210457 non-null  object
#  8   now_arrive_time   210457 non-null  object
#  9   distance          210457 non-null  float64
#  10  next_station      210457 non-null  object
#  11  next_latitude     210457 non-null  float64
#  12  next_longitude    210457 non-null  float64
#  13  next_arrive_time  210457 non-null  int64
# dtypes: float64(5), int64(4), object(5)
# memory usage: 22.5+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91774 entries, 0 to 91773
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               91774 non-null  int64
#  1   date             91774 non-null  object
#  2   route_id         91774 non-null  int64
#  3   vh_id            91774 non-null  int64
#  4   route_nm         91774 non-null  object
#  5   now_latitude     91774 non-null  float64
#  6   now_longitude    91774 non-null  float64
#  7   now_station      91774 non-null  object
#  8   now_arrive_time  91774 non-null  object
#  9   distance         91774 non-null  float64
#  10  next_station     91774 non-null  object
#  11  next_latitude    91774 non-null  float64
#  12  next_longitude   91774 non-null  float64
# dtypes: float64(5), int64(3), object(5)
# memory usage: 9.1+ MB

# %%
# 데이터를 살펴보니 총 14개의 열이 있네요! 하나하나 살펴보겠습니다.

# id: 해당 데이터에서의 고유한 ID
# date: 버스 운행 날짜
# route_id: 버스 노선 ID
# vh_id: 버스 ID
# route_nm: 버스 노선 실제 번호
# now_latitude: 현재 정류소의 위도
# now_longitude: 현재 정류소의 경도
# now_station: 현재 정류소 이름
# now_arrive_time: 현재 정류장에 도착한 시간
# distance: 현재 정류장에서 다음 정류장까지 실제 이동한 거리
# next_station: 다음 정류소 이름
# next_latitude: 다음 정류소의 위도
# next_longitude: 다음 정류소의 경도
# next_arrive_time: 다음 정류장에 도착할 때 까지 걸린 시간(단위: 초)을 의미하며, 우리가 구하고자 하는 값입니다.
# info() 함수를 이용해 데이터 결측치 및 변수들의 타입을 확인해 본 결과,
# train 데이터는 총 14개의 열과 210457개의 행으로 이루어져 있습니다.

# %%
submission = pd.read_csv('C:/Users/endne/OneDrive/바탕 화면/파이썬/알고리즘/dataset/229611_버스 운행시간 예측 경진대회_data/submission_제출양식.csv')

# %%
submission.head()
# Out:
#        id  next_arrive_time
# 0  210457                 0
# 1  210458                 0
# 2  210459                 0
# 3  210460                 0
# 4  210461                 0

# %%
train.head()
# Out:
#    id        date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0  2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1  2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2  2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3  2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4  2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#   now_station now_arrive_time  distance     next_station  next_latitude  \
# 0     제주대학교입구             06시     266.0             제대마을      33.457724
# 1        제대마을             06시     333.0            제대아파트      33.458783
# 2       제대아파트             06시     415.0            제주대학교      33.459893
# 3   남국원(아라방면)             06시     578.0  제주여자중고등학교(아라방면)      33.484860
# 4         도호동             07시     374.0              은남동      33.485822
#
#    next_longitude  next_arrive_time
# 0      126.554014                24
# 1      126.557353                36
# 2      126.561624                40
# 3      126.542928                42
# 4      126.490897                64

# %%
# null 값 확인
train.isnull().sum()
# Out:
# id                  0
# date                0
# route_id            0
# vh_id               0
# route_nm            0
# now_latitude        0
# now_longitude       0
# now_station         0
# now_arrive_time     0
# distance            0
# next_station        0
# next_latitude       0
# next_longitude      0
# next_arrive_time    0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id                 0
# date               0
# route_id           0
# vh_id              0
# route_nm           0
# now_latitude       0
# now_longitude      0
# now_station        0
# now_arrive_time    0
# distance           0
# next_station       0
# next_latitude      0
# next_longitude     0
# dtype: int64

# %%
train['date'] = pd.to_datetime(train['date'])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210457 entries, 0 to 210456
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                210457 non-null  int64
#  1   date              210457 non-null  datetime64[ns]
#  2   route_id          210457 non-null  int64
#  3   vh_id             210457 non-null  int64
#  4   route_nm          210457 non-null  object
#  5   now_latitude      210457 non-null  float64
#  6   now_longitude     210457 non-null  float64
#  7   now_station       210457 non-null  object
#  8   now_arrive_time   210457 non-null  object
#  9   distance          210457 non-null  float64
#  10  next_station      210457 non-null  object
#  11  next_latitude     210457 non-null  float64
#  12  next_longitude    210457 non-null  float64
#  13  next_arrive_time  210457 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(4), object(4)
# memory usage: 22.5+ MB

# %% [markdown]
# ### X, Y 설정

# %%
# 예측할 변수 y 할당
y = train['next_arrive_time']

# y 데이터를 다시 살펴봅니다.
y.head()
# Out:
# 0    24
# 1    36
# 2    40
# 3    42
# 4    64
# Name: next_arrive_time, dtype: int64

# %%
# 학습에 사용할 변수 X 할당
X = train.loc[:,['route_id', 'vh_id','now_latitude', 'now_longitude','distance','next_latitude'
,'next_longitude']]

# %% [markdown]
# ### train_test_split(validation data)

# %%
import sklearn
print(dir(sklearn))
# Out:
# ['__SKLEARN_SETUP__', '__all__', '__builtins__', '__cached__', '__check_build', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_config', '_distributor_init', 'base', 'clone', 'config_context', 'exceptions', 'externals', 'get_config', 'logger', 'logging', 'os', 'random', 'set_config', 'setup_module', 'show_versions', 'sys', 'utils']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=226)

# %%
display(X_train.shape)
display(y_train.shape)
display(X_test.shape)
display(y_test.shape)
# Out:
# (168365, 7)
# (168365,)
# (42092, 7)
# (42092,)

# %% [markdown]
# ### 모델 선택

# %%
from sklearn.linear_model import LinearRegression

# 모델 선언(선택)
model = LinearRegression()

# %%
from sklearn.ensemble import RandomForestRegressor

# 모델 선언(선택)
rf = RandomForestRegressor()

# %% [markdown]
# ### 모델 학습

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# 학습에 사용할 변수 X 할당
test = test.loc[:,['route_id', 'vh_id','now_latitude', 'now_longitude','distance','next_latitude'
,'next_longitude']]

# %% [markdown]
# ### 모델 예측

# %%
# 학습된 모델을 이용해 결괏값 예측 후 상위 10개의 값 확인
predict = model.predict(test)
print('----------------------예측된 데이터의 상위 10개의 값 확인--------------------\n')
print(predict[:10])
# Out:
# ----------------------예측된 데이터의 상위 10개의 값 확인--------------------
#
# [ 92.53416367  98.62254059 102.49940672  96.56355272 112.1088075
#   85.92992021  97.00729294  86.06975063  96.30044748  93.48762004]

# %% [markdown]
# ### 모델 검증

# %%
pred1 = model.predict(X_test)
pred2 = rf.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2_score(y_test, pred1)
# Out:
# 0.2223613616585257

# %%
r2_score(y_test, pred2)
# Out:
# 0.5255261231149209

# %% [markdown]
# ## 데이터 전처리
# ### 위도, 경도 추출하기

# %%
test = pd.read_csv('C:/Users/endne/OneDrive/바탕 화면/파이썬/알고리즘/dataset/229611_버스 운행시간 예측 경진대회_data/test.csv')
train = pd.read_csv('C:/Users/endne/OneDrive/바탕 화면/파이썬/알고리즘/dataset/229611_버스 운행시간 예측 경진대회_data/train.csv')

# %%
train[['next_latitude',	'next_longitude']][:5].values.tolist()
# Out:
# [[33.457724, 126.554014],
#  [33.458783000000004, 126.557353],
#  [33.459893, 126.561624],
#  [33.48486, 126.542928],
#  [33.485822, 126.490897]]

# %%
# !pip install folium    
import folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in c:\users\endne\appdata\roaming\python\python39\site-packages (0.14.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: branca>=0.6.0 in c:\users\endne\appdata\roaming\python\python39\site-packages (from folium) (0.6.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.3)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\endne\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\endne\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\endne\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\endne\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\endne\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\endne\appdata\roaming\python\python39\site-packages)

# %%
import folium

# 좌표 정보
locations = train[['next_latitude', 'next_longitude']][:5].values.tolist()

# 지도의 중심 좌표 설정
center = [33.35, 126.5]

# 지도 (Map) 그리기
m = folium.Map(location=center, zoom_start=11, tiles='cartodbpositron',)

# 점(Circle) 찍기
for i, location in enumerate(locations):
    folium.Circle(
        radius=50,
        location=location,
        tooltip=train['next_station'].loc[i],
        fill=True
    ).add_to(m)

# 경로(PolyLIne) 추가
folium.PolyLine(locations=locations).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c0f4f0e017d1b9c410a52c6680352f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c0f4f0e017d1b9c410a52c6680352f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c0f4f0e017d1b9c410a52c6680352f3 = L.map(
#                 &quot;map_4c0f4f0e017d1b9c410a52c6680352f3&quot;,
#                 {
#                     center: [33.35, 126.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2c1431abd8d74ef263900ea5e00602e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4c0f4f0e017d1b9c410a52c6680352f3);
#
#
#             var circle_c7b537998f77c0aa5aef2a5905dc635d = L.circle(
#                 [33.457724, 126.554014],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4c0f4f0e017d1b9c410a52c6680352f3);
#
#
#             circle_c7b537998f77c0aa5aef2a5905dc635d.bindTooltip(
#                 `&lt;div&gt;
#                      제대마을
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_112e832ed4ed540ea4ae449268d8d14c = L.circle(
#                 [33.458783000000004, 126.557353],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4c0f4f0e017d1b9c410a52c6680352f3);
#
#
#             circle_112e832ed4ed540ea4ae449268d8d14c.bindTooltip(
#                 `&lt;div&gt;
#                      제대아파트
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_16f75621e5919759e7b52b3179bfba23 = L.circle(
#                 [33.459893, 126.561624],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4c0f4f0e017d1b9c410a52c6680352f3);
#
#
#             circle_16f75621e5919759e7b52b3179bfba23.bindTooltip(
#                 `&lt;div&gt;
#                      제주대학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_f0c4c597a781122763b153b9abb6105b = L.circle(
#                 [33.48486, 126.542928],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4c0f4f0e017d1b9c410a52c6680352f3);
#
#
#             circle_f0c4c597a781122763b153b9abb6105b.bindTooltip(
#                 `&lt;div&gt;
#                      제주여자중고등학교(아라방면)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_59b030c3947951abaa83dfa8bb8c112a = L.circle(
#                 [33.485822, 126.490897],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;f

# %%
import folium

# 좌표 정보
locations = train[['next_latitude', 'next_longitude']][:10].values.tolist()

# 지도의 중심 좌표 설정
center = [33.35, 126.5]

# 지도 (Map) 그리기
m = folium.Map(location=center, zoom_start=11, tiles='cartodbpositron',)

# 마커 표시
for i, location in enumerate(locations):
    folium.Marker(
        location=location,
        tooltip=train['next_station'].loc[i],
        fill=True,
        icon=folium.Icon('red', icon='star'),
    ).add_to(m)

# 경로(PolyLIne) 추가
folium.PolyLine(locations=locations).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2337e559d223d63f8f24148a5ab50d26 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2337e559d223d63f8f24148a5ab50d26&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2337e559d223d63f8f24148a5ab50d26 = L.map(
#                 &quot;map_2337e559d223d63f8f24148a5ab50d26&quot;,
#                 {
#                     center: [33.35, 126.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f055a4a135d5ab2025b4bdc5444790d = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2337e559d223d63f8f24148a5ab50d26);
#
#
#             var marker_3d0c4fbdaa4346f78a047581e6ecd746 = L.marker(
#                 [33.457724, 126.554014],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_2337e559d223d63f8f24148a5ab50d26);
#
#
#             var icon_c01aae474ab86420ba95962cbfa90267 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3d0c4fbdaa4346f78a047581e6ecd746.setIcon(icon_c01aae474ab86420ba95962cbfa90267);
#
#
#             marker_3d0c4fbdaa4346f78a047581e6ecd746.bindTooltip(
#                 `&lt;div&gt;
#                      제대마을
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c9d0ab74446faead7b505ba0c644f0b5 = L.marker(
#                 [33.458783000000004, 126.557353],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_2337e559d223d63f8f24148a5ab50d26);
#
#
#             var icon_2af8aedd6e2e6c4fa8c6f9d33742c84c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c9d0ab74446faead7b505ba0c644f0b5.setIcon(icon_2af8aedd6e2e6c4fa8c6f9d33742c84c);
#
#
#             marker_c9d0ab74446faead7b505ba0c644f0b5.bindTooltip(
#                 `&lt;div&gt;
#                      제대아파트
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_31663776de9baf99cd364710250cd947 = L.marker(
#                 [33.459893, 126.561624],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_2337e559d223d63f8f24148a5ab50d26);
#
#
#             var icon_3ad9c85e2b2f9fb3b0866f0f6c065bae = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_31663776de9baf99cd364710250cd947.setIcon(icon_3ad9c85e2b2f9fb3b0866f0f6c065bae);
#
#
#             marker_31663776de9baf99cd364710250cd947.bindTooltip(
#                 `&lt;div&gt;
#                      제주대학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dfbf20c853346133b9661da047641fd2 = L.marker(
#                 [33.48486, 126.542928],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_2337e559d223d63f8f24148a5ab50d26);
#
#
#             var icon_1c5ebde2f18f2e08068c5ca9cb05042c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dfbf20c853346133b9661da047641fd2.setIcon(icon_1c5ebde2f18f2e08068c5ca9cb05042c);
#
#
#             marker_dfbf20c853346133b9661da047641fd2.bindTooltip(
#                 `&lt;div&gt;
#                      제주여자중고등학교(아라방면)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5b77557a48f3f28848a67451b2c21e09 = L.marker(
#                 [33.485822, 126.490897],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_2337e559d223d63f8f24148a5ab50d26);
#
#
#             var icon_af02ace1cabde853c2668da42696f392 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa

# %% [markdown]
# ### test 데이텨에만 존재하는 정류소 확인

# %%
# set(test['now_station'].unique())

# %%
train['now_station'].unique()
# Out:
# array(['제주대학교입구', '제대마을', '제대아파트', '남국원(아라방면)', '도호동', '한라중학교/부영아파트',
#        '대림2차아파트', '롯데마트', '원노형', '노형오거리', '남녕고등학교', '한라병원', '삼무공원사거리',
#        '제원아파트', '은남동', '연동주민센터', '제주도청 신제주로터리', '월구마을', '동성마을', '제주버스터미널',
#        '한국병원', '남서광마을입구', '남서광마을', '탐라장애인 종합복지관', '제주시청(아라방면)',
#        '고산동산(아라방면)', '제주지방법원(아라방면)', '아라초등학교', '아라주공아파트', '인다마을', '남국사',
#        '연동대림1차아파트', '케이티앤지', '제주중앙여자고등학교(아라방면)', '제주여자중고등학교(아라방면)',
#        '제주대학교병원', '연동입구', '오라3동', '죽성마을 입구', '제주대학교', '부영아파트',
#        '제주시청(광양방면)', '고산동산(광양방면)', '제주여자중고등학교(광양방면)', '아라동주민센터',
#        '남국원(광양방면)', '제주지방법원(광양방면)', '제주중앙여자고등학교(광양방면)', '웃 인다 마을',
#        '제주대학교 입구', '광양사거리', '홍랑로입구', '용천마을', '동산교', '오라오거리', '명신마을',
#        '월랑마을 남녕고등학교', '제주제일고등학교', '으뜸마을', '탐라도서관', '제주고등학교/중흥S클래스',
#        '보성시장', '시민회관', '중앙로(현대약국)', '관덕정', '서문시장', '용담1동주민센터', '용문사거리',
#        '용문마을', '용문마을회관', '화물청사입구', '중흥S클래스아파트', '시티주유소', '다호마을',
#        '제주국제공항(신제주방면)', '노형초등학교', '제주국제공항(구제주방면)', '월성 마을', '제주중학교/제주향교',
#        '중앙로(국민은행)', '삼성초등학교', '광양', '제주한라대학교', '정존마을', '동광양', '문예회관',
#        '인화초등학교', '천수동', '고으니모르 국립제주박물관', '오현중고등학교', '화북초등학교', '화북남문',
#        '제주동중학교', '삼양초등학교', '원당분화원', '문서교', '조천리', '해양연구소', '함덕비석거리',
#        '함덕농협지소', '함덕리 3구', '함덕환승정류장(함덕해수욕장)', '함덕리(4구)', '911의원', '영등물',
#        '김녕환승정류장(김녕초등학교)', '지경곰', '월정리', '한동리서동', '한동리', '평대리사무소', '평대리동동',
#        '세화리시장2동', '세화환승정류장(세화리)', '세화리구좌농협', '해녀박물관입구', '하도리', '종달리',
#        '종달초등학교', '시흥리', '시흥리사무소', '성산국민체육센터', '성산고입구삼거리', '오조리 입구',
#        '성산고등학교', '성산포 수협', '고성리 구 성산농협', '성산읍사무소', '난산입구', '신산리', '삼달교차로',
#        '신천리취락구조', '신천리', '하천하동', '표선초등학교', '표선환승정류장(표선리 제주은행)',
#        '성산포수협표선지점', '표선오일시장', '그린카센터', '한지동', '가흥동', '세화2리사무소', '가마초등학교',
#        '샤인빌리조트입구', '어촌계입구', '씨사이드홈', '남원읍사무소', '남원포구입구', '남원1리사무소',
#        '동부보건소', '위미3리 마을회관', '위미3리', '대원상동', '뒤통모루', '신례2리교차로',
#        '삼성여자고등학교', '세기아파트', '주공 3 4단지', '동문로터리', '현대산부인과', '청소년문화의집',
#        '구 터미널', '아랑조을거리 입구', '평생학습관', 'LH아파트', '서성동', '위미초등학교', '동원산업',
#        '성산리입구', '성산일출봉입구', '오조해녀의집', '하도리면수동', '평대초등학교', '구좌중앙초등학교',
#        '동성동', '김녕리', '조천읍사무소', '대섬입구', '제주버스터미널(가상정류소)', '제주대학교교육대학',
#        '거로 입구', '화북주공아파트', '삼양2동', '신촌초등학교', '조천환승정류장(조천리사무소)', '북촌리해동',
#        '북촌리', '동복리', '동복리관광체험어장', '남흘동', '행원리', '행원농공단지', '계룡동', '성산항입구',
#        '성산리 취락구조', '광치기해변', '성산환승정류장(고성리 한국물류)', '고성리 성산농협', '혼인지입구',
#        '희진주유소', '한지교차로', '토산관광지구입구', '산열이통입구', '수농원', '태흥3리', '태흥초등학교',
#        '광지동', '남원생활체육관', '농협주유소', '창남거리', '비석거리', '광대왓', '하도초등학교',
#        '하도리 서문동', '조천체육관', '주암주택', '동복리휴게소', '김녕해수욕장', '금산목', '하도리동동',
#        '화성농장', '신산환승정류장(성산농협신산지점)', '신흥1번지', '신흥교차로', '태흥3리사무소', '무도동',
#        '종보존연구센터', '위미문화의집', '하례1리입구', '남성마을입구', '서귀포여자고등학교', '고래왓',
#        '만장굴입구', '삼양검문소', '신촌리', '북촌다려마을', '신양리입구', '성산농협종합유통센터', '신풍리하동',
#        '신흥리취락구조', '서소동', '진은동', '상원동', '효돈농협하나로마트', '신성동', '송천교', '세천동',
#        '맹살공원', '상효입구', '토평 보목입구', '남원취락구조', '충혼묘지', '조천초등학교', '하천리취락구조',
#        '표선환승정류장(표선리사무소)', '위미1리사무소', '망장포 입구', '서귀포버스터미널(가상정류소)', '수모루',
#        '여 의 물', '삼매봉', '서귀포시 구 버스터미널', '매일올레시장 7번입구', '삼아아파트', '효돈축구공원',
#        '공천포', '대화동', '표선파출소', '온평초등학교', '성산환승정류장(고성리 회전교차로)', '고성리제주은행',
#        '금붕사', '함덕리 4구', '조천만세동산', '조천환승정류장(조천우체국)', '삼양동주민센터', '국립제주박물관',
#        '우당도서관', '사라봉', '사라봉오거리', '제주여자상업고등학교', '제일교 동문시장입구', '동문성당',
#        '신산로', '성산리', '농협 하나로마트', '오조리', '월정리 용천동', '서귀포동부도서관', '대륜동주민센터',
#        '폭낭사거리', '온평리', '진드르', '하도리창흥동', '원당봉', '보목입구', '고망난돌입구',
#        '난산입구(성산기상대)', '효돈중학교', '효돈초등학교', '신협', '신효동', '월라봉', '평대리서동',
#        '앞동산', '신효', '구좌보건지소', '삼매봉입구', '세화고등학교', '상도마을회관', '오조리상동입구',
#        '고성오일시장', '오조리하동', '사회복지법인 춘강', '산천단', '제주국제대학교', '입석동',
#        '하례환승정류장(하례리입구)', '평안전문요양원', '뒷빌레', '토평마을회관', '답다니', '영천동주민센터',
#        '양지(추모)공원', '제주의료원', '종합사격장', '견월교', '교래입구', '서귀포산업과학고등학교',
#        '공업단지 입구', '오희준 공원', '흙통', '중앙로터리', '제주컨트리클럽', '성판악', '수악교',
#        '고도농원', '한라생태숲', '마방목지', '꽃동산', '법호촌입구', '법호촌 온성학교', '산천단 한국폴리텍대학',
#        '한라산 둘레길', '효례교', '상도리 세화고등학교', '전경대 입구', '하도리 개긋물'], dtype=object)

# %%
set(test['now_station'].unique()) - set(train['now_station'].unique())
# Out:
# {'제주한라대학교(종점)'}

# %%
set(train['now_station'].unique()) - set(test['now_station'].unique())
# Out:
# set()

# %%
train[train['now_station'] == '제주한라대학교(종점)']
# Out:
# Empty DataFrame
# Columns: [id, date, route_id, vh_id, route_nm, now_latitude, now_longitude, now_station, now_arrive_time, distance, next_station, next_latitude, next_longitude, next_arrive_time]
# Index: []

# %%
test[test['now_station'] == '제주한라대학교(종점)']
# Out:
#           id        date   route_id    vh_id route_nm  now_latitude  \
# 2868  213330  2019-10-29  405136521  7997001   365-21     33.477787
#
#       now_longitude  now_station now_arrive_time  distance next_station  \
# 2868      126.47574  제주한라대학교(종점)             07시     431.0        시티주유소
#
#       next_latitude  next_longitude
# 2868      33.476401      126.479759

# %%
print(list(a))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\endne\OneDrive\바탕 화면\파이썬\알고리즘\git 연습\데이터분석\bus.ipynb Cell 48 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/endne/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/%ED%8C%8C%EC%9D%B4%EC%8D%AC/%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98/git%20%EC%97%B0%EC%8A%B5/%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D/bus.ipynb#X64sZmlsZQ%3D%3D?line=0'>1</a> print(list(a))
#
# NameError: name 'a' is not defined

# %%
train[train['next_station'] == '제주한라대학교(종점)']
# Out:
#             id        date   route_id    vh_id route_nm  now_latitude  \
# 3005      3005  2019-10-15  405136521  7997001   365-21     33.476401
# 3085      3085  2019-10-15  405136521  7997001   365-21     33.476401
# 3100      3100  2019-10-15  405136521  7997001   365-21     33.476401
# 3145      3145  2019-10-15  405136521  7997001   365-21     33.476401
# 3191      3191  2019-10-15  405136521  7997031   365-21     33.476401
# ...        ...         ...        ...      ...      ...           ...
# 199507  199507  2019-10-28  405136521  7997087   365-21     33.476401
# 199554  199554  2019-10-28  405136521  7997089   365-21     33.476401
# 199634  199634  2019-10-28  405136521  7997089   365-21     33.476401
# 199675  199675  2019-10-28  405136521  7997089   365-21     33.476401
# 199709  199709  2019-10-28  405136521  7997089   365-21     33.476401
#
#         now_longitude now_station now_arrive_time  distance next_station  \
# 3005       126.479759       시티주유소             07시     431.0  제주한라대학교(종점)
# 3085       126.479759       시티주유소             14시     431.0  제주한라대학교(종점)
# 3100       126.479759       시티주유소             18시     431.0  제주한라대학교(종점)
# 3145       126.479759       시티주유소             22시     431.0  제주한라대학교(종점)
# 3191       126.479759       시티주유소             09시     431.0  제주한라대학교(종점)
# ...               ...         ...             ...       ...          ...
# 199507     126.479759       시티주유소             21시     431.0  제주한라대학교(종점)
# 199554     126.479759       시티주유소             09시     431.0  제주한라대학교(종점)
# 199634     126.479759       시티주유소             16시     431.0  제주한라대학교(종점)
# 199675     126.479759       시티주유소             19시     431.0  제주한라대학교(종점)
# 199709     126.479759       시티주유소             23시     431.0  제주한라대학교(종점)
#
#         next_latitude  next_longitude  next_arrive_time
# 3005        33.477787       126.47574                48
# 3085        33.477787       126.47574                60
# 3100        33.477787       126.47574              2268
# 3145        33.477787       126.47574                70
# 3191        33.477787       126.47574                34
# ...               ...             ...               ...
# 199507      33.477787       126.47574              1736
# 199554      33.477787       126.47574               778
# 199634      33.477787       126.47574              1206
# 199675      33.477787       126.47574              1428
# 199709      33.477787       126.47574                46
#
# [227 rows x 14 columns]

# %%
test[test['next_station'] == '제주한라대학교(종점)']
# Out:
#            id        date   route_id    vh_id route_nm  now_latitude  \
# 2906   213368  2019-10-29  405136521  7997001   365-21     33.476401
# 2992   213454  2019-10-29  405136521  7997001   365-21     33.476401
# 3020   213482  2019-10-29  405136521  7997001   365-21     33.476401
# 3198   213662  2019-10-29  405136521  7997031   365-21     33.476401
# 3238   213702  2019-10-29  405136521  7997070   365-21     33.476401
# ...       ...         ...        ...      ...      ...           ...
# 82692  293268  2019-11-05  405136521  7997087   365-21     33.476401
# 82758  293334  2019-11-05  405136521  7997087   365-21     33.476401
# 82793  293369  2019-11-05  405136521  7997087   365-21     33.476401
# 82838  293414  2019-11-05  405136521  7997087   365-21     33.476401
# 82957  293533  2019-11-05  405136521  7997089   365-21     33.476401
#
#        now_longitude now_station now_arrive_time  distance next_station  \
# 2906      126.479759       시티주유소             10시     431.0  제주한라대학교(종점)
# 2992      126.479759       시티주유소             17시     431.0  제주한라대학교(종점)
# 3020      126.479759       시티주유소             21시     431.0  제주한라대학교(종점)
# 3198      126.479759       시티주유소             21시     431.0  제주한라대학교(종점)
# 3238      126.479759       시티주유소             09시     431.0  제주한라대학교(종점)
# ...              ...         ...             ...       ...          ...
# 82692     126.479759       시티주유소             07시     431.0  제주한라대학교(종점)
# 82758     126.479759       시티주유소             14시     431.0  제주한라대학교(종점)
# 82793     126.479759       시티주유소             18시     431.0  제주한라대학교(종점)
# 82838     126.479759       시티주유소             22시     431.0  제주한라대학교(종점)
# 82957     126.479759       시티주유소             17시     431.0  제주한라대학교(종점)
#
#        next_latitude  next_longitude
# 2906       33.477787       126.47574
# 2992       33.477787       126.47574
# 3020       33.477787       126.47574
# 3198       33.477787       126.47574
# 3238       33.477787       126.47574
# ...              ...             ...
# 82692      33.477787       126.47574
# 82758      33.477787       126.47574
# 82793      33.477787       126.47574
# 82838      33.477787       126.47574
# 82957      33.477787       126.47574
#
# [77 rows x 13 columns]

# %% [markdown]
# ### 값에 숫자 부여
# train의 next_station 에 '제주한라대학교(종점)'이 존재
#
# test 데이터에만 존재하고, train 데이터에는 존재하지 않으면 예측을 할 수 없습니다.
# 이 문제를 해결하기 위해 train셋의 now_station과 next_station을 모두 합쳐서 dict로 만들어 줍니다.
#
# + route_nm 도 포함하여 dict를 구성하겠습니다.

# %%
my_list = list(train['route_nm'].unique()) + list(train['now_station'].unique()) + list(train['next_station'].unique())

# %%
my_list
# Out:
# ['360-1',
#  '360-2',
#  '360-7',
#  '360-12',
#  '365-21',
#  '365-22',
#  '201-11',
#  '201-12',
#  '201-13',
#  '201-14',
#  '201-15',
#  '201-16',
#  '201-17',
#  '201-18',
#  '201-21',
#  '201-22',
#  '201-24',
#  '201-26',
#  '201-27',
#  '281-1',
#  '281-2',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '남국원(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '남국사',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '제주대학교병원',
#  '연동입구',
#  '오라3동',
#  '죽성마을 입구',
#  '제주대학교',
#  '부영아파트',
#  '제주시청(광양방면)',
#  '고산동산(광양방면)',
#  '제주여자중고등학교(광양방면)',
#  '아라동주민센터',
#  '남국원(광양방면)',
#  '제주지방법원(광양방면)',
#  '제주중앙여자고등학교(광양방면)',
#  '웃 인다 마을',
#  '제주대학교 입구',
#  '광양사거리',
#  '홍랑로입구',
#  '용천마을',
#  '동산교',
#  '오라오거리',
#  '명신마을',
#  '월랑마을 남녕고등학교',
#  '제주제일고등학교',
#  '으뜸마을',
#  '탐라도서관',
#  '제주고등학교/중흥S클래스',
#  '보성시장',
#  '시민회관',
#  '중앙로(현대약국)',
#  '관덕정',
#  '서문시장',
#  '용담1동주민센터',
#  '용문사거리',
#  '용문마을',
#  '용문마을회관',
#  '화물청사입구',
#  '중흥S클래스아파트',
#  '시티주유소',
#  '다호마을',
#  '제주국제공항(신제주방면)',
#  '노형초등학교',
#  '제주국제공항(구제주방면)',
#  '월성 마을',
#  '제주중학교/제주향교',
#  '중앙로(국민은행)',
#  '삼성초등학교',
#  '광양',
#  '제주한라대학교',
#  '정존마을',
#  '동광양',
#  '문예회관',
#  '인화초등학교',
#  '천수동',
#  '고으니모르 국립제주박물관',
#  '오현중고등학교',
#  '화북초등학교',
#  '화북남문',
#  '제주동중학교',
#  '삼양초등학교',
#  '원당분화원',
#  '문서교',
#  '조천리',
#  '해양연구소',
#  '함덕비석거리',
#  '함덕농협지소',
#  '함덕리 3구',
#  '함덕환승정류장(함덕해수욕장)',
#  '함덕리(4구)',
#  '911의원',
#  '영등물',
#  '김녕환승정류장(김녕초등학교)',
#  '지경곰',
#  '월정리',
#  '한동리서동',
#  '한동리',
#  '평대리사무소',
#  '평대리동동',
#  '세화리시장2동',
#  '세화환승정류장(세화리)',
#  '세화리구좌농협',
#  '해녀박물관입구',
#  '하도리',
#  '종달리',
#  '종달초등학교',
#  '시흥리',
#  '시흥리사무소',
#  '성산국민체육센터',
#  '성산고입구삼거리',
#  '오조리 입구',
#  '성산고등학교',
#  '성산포 수협',
#  '고성리 구 성산농협',
#  '성산읍사무소',
#  '난산입구',
#  '신산리',
#  '삼달교차로',
#  '신천리취락구조',
#  '신천리',
#  '하천하동',
#  '표선초등학교',
#  '표선환승정류장(표선리 제주은행)',
#  '성산포수협표선지점',
#  '표선오일시장',
#  '그린카센터',
#  '한지동',
#  '가흥동',
#  '세화2리사무소',
#  '가마초등학교',
#  '샤인빌리조트입구',
#  '어촌계입구',
#  '씨사이드홈',
#  '남원읍사무소',
#  '남원포구입구',
#  '남원1리사무소',
#  '동부보건소',
#  '위미3리 마을회관',
#  '위미3리',
#  '대원상동',
#  '뒤통모루',
#  '신례2리교차로',
#  '삼성여자고등학교',
#  '세기아파트',
#  '주공 3 4단지',
#  '동문로터리',
#  '현대산부인과',
#  '청소년문화의집',
#  '구 터미널',
#  '아랑조을거리 입구',
#  '평생학습관',
#  'LH아파트',
#  '서성동',
#  '위미초등학교',
#  '동원산업',
#  '성산리입구',
#  '성산일출봉입구',
#  '오조해녀의집',
#  '하도리면수동',
#  '평대초등학교',
#  '구좌중앙초등학교',
#  '동성동',
#  '김녕리',
#  '조천읍사무소',
#  '대섬입구',
#  '제주버스터미널(가상정류소)',
#  '제주대학교교육대학',
#  '거로 입구',
#  '화북주공아파트',
#  '삼양2동',
#  '신촌초등학교',
#  '조천환승정류장(조천리사무소)',
#  '북촌리해동',
#  '북촌리',
#  '동복리',
#  '동복리관광체험어장',
#  '남흘동',
#  '행원리',
#  '행원농공단지',
#  '계룡동',
#  '성산항입구',
#  '성산리 취락구조',
#  '광치기해변',
#  '성산환승정류장(고성리 한국물류)',
#  '고성리 성산농협',
#  '혼인지입구',
#  '희진주유소',
#  '한지교차로',
#  '토산관광지구입구',
#  '산열이통입구',
#  '수농원',
#  '태흥3리',
#  '태흥초등학교',
#  '광지동',
#  '남원생활체육관',
#  '농협주유소',
#  '창남거리',
#  '비석거리',
#  '광대왓',
#  '하도초등학교',
#  '하도리 서문동',
#  '조천체육관',
#  '주암주택',
#  '동복리휴게소',
#  '김녕해수욕장',
#  '금산목',
#  '하도리동동',
#  '화성농장',
#  '신산환승정류장(성산농협신산지점)',
#  '신흥1번지',
#  '신흥교차로',
#  '태흥3리사무소',
#  '무도동',
#  '종보존연구센터',
#  '위미문화의집',
#  '하례1리입구',
#  '남성마을입구',
#  '서귀포여자고등학교',
#  '고래왓',
#  '만장굴입구',
#  '삼양검문소',
#  '신촌리',
#  '북촌다려마을',
#  '신양리입구',
#  '성산농협종합유통센터',
#  '신풍리하동',
#  '신흥리취락구조',
#  '서소동',
#  '진은동',
#  '상원동',
#  '효돈농협하나로마트',
#  '신성동',
#  '송천교',
#  '세천동',
#  '맹살공원',
#  '상효입구',
#  '토평 보목입구',
#  '남원취락구조',
#  '충혼묘지',
#  '조천초등학교',
#  '하천리취락구조',
#  '표선환승정류장(표선리사무소)',
#  '위미1리사무소',
#  '망장포 입구',
#  '서귀포버스터미널(가상정류소)',
#  '수모루',
#  '여 의 물',
#  '삼매봉',
#  '서귀포시 구 버스터미널',
#  '매일올레시장 7번입구',
#  '삼아아파트',
#  '효돈축구공원',
#  '공천포',
#  '대화동',
#  '표선파출소',
#  '온평초등학교',
#  '성산환승정류장(고성리 회전교차로)',
#  '고성리제주은행',
#  '금붕사',
#  '함덕리 4구',
#  '조천만세동산',
#  '조천환승정류장(조천우체국)',
#  '삼양동주민센터',
#  '국립제주박물관',
#  '우당도서관',
#  '사라봉',
#  '사라봉오거리',
#  '제주여자상업고등학교',
#  '제일교 동문시장입구',
#  '동문성당',
#  '신산로',
#  '성산리',
#  '농협 하나로마트',
#  '오조리',
#  '월정리 용천동',
#  '서귀포동부도서관',
#  '대륜동주민센터',
#  '폭낭사거리',
#  '온평리',
#  '진드르',
#  '하도리창흥동',
#  '원당봉',
#  '보목입구',
#  '고망난돌입구',
#  '난산입구(성산기상대)',
#  '효돈중학교',
#  '효돈초등학교',
#  '신협',
#  '신효동',
#  '월라봉',
#  '평대리서동',
#  '앞동산',
#  '신효',
#  '구좌보건지소',
#  '삼매봉입구',
#  '세화고등학교',
#  '상도마을회관',
#  '오조리상동입구',
#  '고성오일시장',
#  '오조리하동',
#  '사회복지법인 춘강',
#  '산천단',
#  '제주국제대학교',
#  '입석동',
#  '하례환승정류장(하례리입구)',
#  '평안전문요양원',
#  '뒷빌레',
#  '토평마을회관',
#  '답다니',
#  '영천동주민센터',
#  '양지(추모)공원',
#  '제주의료원',
#  '종합사격장',
#  '견월교',
#  '교래입구',
#  '서귀포산업과학고등학교',
#  '공업단지 입구',
#  '오희준 공원',
#  '흙통',
#  '중앙로터리',
#  '제주컨트리클럽',
#  '성판악',
#  '수악교',
#  '고도농원',
#  '한라생태숲',
#  '마방목지',
#  '꽃동산',
#  '법호촌입구',
#  '법호촌 온성학교',
#  '산천단 한국폴리텍대학',
#  '한라산 둘레길',
#  '효례교',
#  '상도리 세화고등학교',
#  '전경대 입구',
#  '하도리 개긋물',
#  '제대마을',
#  '제대아파트',
#  '제주대학교',
#  '제주여자중고등학교(아라방면)',
#  '은남동',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '제주대학교병원',
#  '제주대학교입구',
#  '케이티앤지',
#  '롯데마트',
#  '남국원(아라방면)',
#  '죽성마을 입구',
#  '오라3동',
#  '월구마을',
#  '남국사',
#  '한라중학교/부영아파트',
#  '고산동산(광양방면)',
#  '제주지방법원(광양방면)',
#  '남국원(광양방면)',
#  '아라동주민센터',
#  '제주여자중고등학교(광양방면)',
#  '제주시청(광양방면)',
#  '제주중앙여자고등학교(광양방면)',
#  '제주대학교 입구',
#  '웃 인다 마을',
#  '광양사거리',
#  '홍랑로입구',
#  '용천마을',
#  '동산교',
#  '오라오거리',
#  '명신마을',
#  '월랑마을 남녕고등학교',
#  '제주제일고등학교',
#  '으뜸마을',
#  '탐라도서관',
#  '제주고등학교/중흥S클래스',
#  '부영아파트',
#  '보성시장',
#  '시민회관',
#  '중앙로(현대약국)',
#  '관덕정',
#  '서문시장',
#  '용담1동주민센터',
#  '용문사거리',
#  '용문마을',
#  '용문마을회관',
#  '화물청사입구',
#  '제주국제공항(신제주방면)',
#  '중흥S클래스아파트',
#  '시티주유소',
#  '제주한라대학교(종점)',
#  '다호마을',
#  '제주국제공항(구제주방면)',
#  '월성 마을',
#  '제주중학교/제주향교',
#  '중앙로(국민은행)',
#  '삼성초등학교',
#  '광양',
#  '정존마을',
#  '노형초등학교',
#  '동광양',
#  '문예회관',
#  '인화초등학교',
#  '천수동',
#  '고으니모르 국립제주박물관',
#  '제주대학교교육대학',
#  '화북초등학교',
#  '화북남문',
#  '제주동중학교',
#  '화북주공아파트',
#  '원당분화원',
#  '삼양검문소',
#  '신촌초등학교',
#  '조천환승정류장(조천리사무소)',
#  '함덕비석거리',
#  '함덕농협지소',
#  '함덕리 3구',
#  '함덕환승정류장(함덕해수욕장)',
#  '함덕리(4구)',
#  '911의원',
#  '북촌리해동',
#  '남흘동',
#  '동성동',
#  '만장굴입구',
#  '구좌중앙초등학교',
#  '한동리',
#  '계룡동',
#  '평대리동동',
#  '세화리시장2동',
#  '세화환승정류장(세화리)',
#  '세화리구좌농협',
#  '해녀박물관입구',
#  '하도리면수동',
#  '하도리동동',
#  '종달초등학교',
#  '시흥리',
#  '시흥리사무소',
#  '성산국민체육센터',
#  '성산고입구삼거리',
#  '오조리 입구',
#  '성산고등학교',
#  '오조해녀의집',
#  '고성리 구 성산농협',
#  '성산환승정류장(고성리 한국물류)',
#  '신양리입구',
#  '신산리',
#  '신산환승정류장(성산농협신산지점)',
#  '신풍리하동',
#  '신천리',
#  '하천하동',
#  '표선초등학교',
#  '표선환승정류장(표선리 제주은행)',
#  '성산포수협표선지점',
#  '표선오일시장',
#  '그린카센터',
#  '동원산업',
#  '가흥동',
#  '세화2리사무소',
#  '가마초등학교',
#  '샤인빌리조트입구',
#  '토산관광지구입구',
#  '태흥초등학교',
#  '남원읍사무소',
#  '남원포구입구',
#  '남원1리사무소',
#  '광지동',
#  '남원취락구조',
#  '위미3리',
#  '종보존연구센터',
#  '뒤통모루',
#  '상원동',
#  '공천포',
#  '창남거리',
#  '주공 3 4단지',
#  '동문로터리',
#  '현대산부인과',
#  '청소년문화의집',
#  '구 터미널',
#  '아랑조을거리 입구',
#  '평생학습관',
#  '남성마을입구',
#  '광대왓',
#  '위미초등학교',
#  '위미문화의집',
#  '씨사이드홈',
#  '한지동',
#  '신천리취락구조',
#  '성산포 수협',
#  '성산일출봉입구',
#  '성산리 취락구조',
#  '종달리',
#  '평대리서동',
#  '한동리서동',
#  '월정리',
#  '월정리 용천동',
#  '김녕환승정류장(김녕초등학교)',
#  '김녕리',
#  '대섬입구',
#  '신촌리',
#  '거로 입구',
#  '오현중고등학교',
#  '삼양2동',
#  '삼양초등학교',
#  '조천리',
#  '조천체육관',
#  '북촌리',
#  '북촌다려마을',
#  '동복리관광체험어장',
#  '영등물',
#  '행원농공단지',
#  '성산리입구',
#  '광치기해변',
#  '고성리 성산농협',
#  '성산읍사무소',
#  '온평초등학교',
#  '삼달교차로',
#  '한지교차로',
#  '산열이통입구',
#  '송천교',
#  '신흥교차로',
#  '태흥3리사무소',
#  '무도동',
#  '남원생활체육관',
#  '동부보건소',
#  '서성동',
#  '농협주유소',
#  '신례2리교차로',
#  '비석거리',
#  '세기아파트',
#  '고래왓',
#  '하도리 서문동',
#  '행원리',
#  '동복리',
#  '주암주택',
#  '충혼묘지',
#  '김녕해수욕장',
#  '지경곰',
#  '금산목',
#  '하도리',
#  '하도리창흥동',
#  '난산입구',
#  '희진주유소',
#  '수농원',
#  '신흥리취락구조',
#  '어촌계입구',
#  '서소동',
#  '세천동',
#  '효례교',
#  '삼매봉입구',
#  'LH아파트',
#  '서귀포버스터미널',
#  '대원상동',
#  '위미3리 마을회관',
#  '신성동',
#  '조천읍사무소',
#  '진드르',
#  '동복리휴게소',
#  '성산농협종합유통센터',
#  '혼인지입구',
#  '고망난돌입구',
#  '태흥3리',
#  '진은동',
#  '효돈축구공원',
#  '성산항입구',
#  '신흥1번지',
#  '효돈농협하나로마트',
#  '토평 보목입구',
#  '삼성여자고등학교',
#  '하천리취락구조',
#  '표선환승정류장(표선리사무소)',
#  '표선파출소',
#  '대화동',
#  '하례1리입구',
#  '보목입구',
#  '매일올레시장 7번입구',
#  '대륜동주민센터',
#  '수모루',
#  '서귀포여자고등학교',
#  '여 의 물',
#  '삼매봉',
#  '서귀포시 구 버스터미널',
#  '삼아아파트',
#  '맹살공원',
#  '망장포 입구',
#  '위미1리사무소',
#  '고성리제주은행',
#  '성산리',
#  '금붕사',
#  '평대리사무소',
#  '평대초등학교',
#  '해양연구소',
#  '조천만세동산',
#  '조천환승정류장(조천우체국)',
#  '조천초등학교',
#  '문서교',
#  '국립제주박물관',
#  '우당도서관',
#  '사라봉',
#  '사라봉오거리',
#  '제주여자상업고등학교',
#  '제일교 동문시장입구',
#  '동문성당',
#  '신산로',
#  '제주버스터미널(종점)',
#  '함덕리 4구',
#  '성산환승정류장(고성리 회전교차로)',
#  '폭낭사거리',
#  '농협 하나로마트',
#  '오조리',
#  '상효입구',
#  '서귀포버스터미널(가상정류소)',
#  '난산입구(성산기상대)',
#  '원당봉',
#  '삼양동주민센터',
#  '화성농장',
#  '하도초등학교',
#  '효돈초등학교',
#  '신협',
#  '신효동',
#  '월라봉',
#  '효돈중학교',
#  '신효',
#  '앞동산',
#  '온평리',
#  '상도리 세화고등학교',
#  '구좌보건지소',
#  '하도리 개긋물',
#  '세화고등학교',
#  '고성오일시장',
#  '오조리하동',
#  '오조리상동입구',
#  '사회복지법인 춘강',
#  '산천단',
#  '제주의료원',
#  '양지(추모)공원',
#  '하례환승정류장(하례리입구)',
#  '서귀포산업과학고등학교',
#  '뒷빌레',
#  '토평마을회관',
#  '영천동주민센터',
#  '중앙로터리',
#  '제주국제대학교',
#  '종합사격장',
#  '교래입구',
#  '성판악',
#  '법호촌 온성학교',
#  '평안전문요양원',
#  '오희준 공원',
#  '흙통',
#  '답다니',
#  '입석동',
#  '수악교',
#  '공업단지 입구',
#  '마방목지',
#  '제주컨트리클럽',
#  '한라생태숲',
#  '견월교',
#  '꽃동산',
#  '산천단 한국폴리텍대학',
#  '법호촌입구',
#  '고도농원',
#  '한라산 둘레길',
#  '상도마을회관',
#  '전경대 입구',
#  '서귀포동부도서관',
#  '제주버스터미널(가상정류소)',
#  '제주한라대학교']

# %%
my_dict = {text : i for i, text in enumerate(my_list)}
my_dict
# Out:
# {'360-1': 0,
#  '360-2': 1,
#  '360-7': 2,
#  '360-12': 3,
#  '365-21': 4,
#  '365-22': 5,
#  '201-11': 6,
#  '201-12': 7,
#  '201-13': 8,
#  '201-14': 9,
#  '201-15': 10,
#  '201-16': 11,
#  '201-17': 12,
#  '201-18': 13,
#  '201-21': 14,
#  '201-22': 15,
#  '201-24': 16,
#  '201-26': 17,
#  '201-27': 18,
#  '281-1': 19,
#  '281-2': 20,
#  '제주대학교입구': 400,
#  '제대마을': 369,
#  '제대아파트': 370,
#  '남국원(아라방면)': 403,
#  '도호동': 382,
#  '한라중학교/부영아파트': 408,
#  '대림2차아파트': 374,
#  '롯데마트': 402,
#  '원노형': 376,
#  '노형오거리': 377,
#  '남녕고등학교': 378,
#  '한라병원': 379,
#  '삼무공원사거리': 380,
#  '제원아파트': 381,
#  '은남동': 373,
#  '연동주민센터': 383,
#  '제주도청 신제주로터리': 384,
#  '월구마을': 406,
#  '동성마을': 386,
#  '제주버스터미널': 387,
#  '한국병원': 388,
#  '남서광마을입구': 389,
#  '남서광마을': 390,
#  '탐라장애인 종합복지관': 391,
#  '제주시청(아라방면)': 392,
#  '고산동산(아라방면)': 393,
#  '제주지방법원(아라방면)': 394,
#  '아라초등학교': 396,
#  '아라주공아파트': 397,
#  '인다마을': 398,
#  '남국사': 407,
#  '연동대림1차아파트': 375,
#  '케이티앤지': 401,
#  '제주중앙여자고등학교(아라방면)': 395,
#  '제주여자중고등학교(아라방면)': 372,
#  '제주대학교병원': 399,
#  '연동입구': 385,
#  '오라3동': 405,
#  '죽성마을 입구': 404,
#  '제주대학교': 371,
#  '부영아파트': 429,
#  '제주시청(광양방면)': 414,
#  '고산동산(광양방면)': 409,
#  '제주여자중고등학교(광양방면)': 413,
#  '아라동주민센터': 412,
#  '남국원(광양방면)': 411,
#  '제주지방법원(광양방면)': 410,
#  '제주중앙여자고등학교(광양방면)': 415,
#  '웃 인다 마을': 417,
#  '제주대학교 입구': 416,
#  '광양사거리': 418,
#  '홍랑로입구': 419,
#  '용천마을': 420,
#  '동산교': 421,
#  '오라오거리': 422,
#  '명신마을': 423,
#  '월랑마을 남녕고등학교': 424,
#  '제주제일고등학교': 425,
#  '으뜸마을': 426,
#  '탐라도서관': 427,
#  '제주고등학교/중흥S클래스': 428,
#  '보성시장': 430,
#  '시민회관': 431,
#  '중앙로(현대약국)': 432,
#  '관덕정': 433,
#  '서문시장': 434,
#  '용담1동주민센터': 435,
#  '용문사거리': 436,
#  '용문마을': 437,
#  '용문마을회관': 438,
#  '화물청사입구': 439,
#  '중흥S클래스아파트': 441,
#  '시티주유소': 442,
#  '다호마을': 444,
#  '제주국제공항(신제주방면)': 440,
#  '노형초등학교': 452,
#  '제주국제공항(구제주방면)': 445,
#  '월성 마을': 446,
#  '제주중학교/제주향교': 447,
#  '중앙로(국민은행)': 448,
#  '삼성초등학교': 449,
#  '광양': 450,
#  '제주한라대학교': 719,
#  '정존마을': 451,
#  '동광양': 453,
#  '문예회관': 454,
#  '인화초등학교': 455,
#  '천수동': 456,
#  '고으니모르 국립제주박물관': 457,
#  '오현중고등학교': 553,
#  '화북초등학교': 459,
#  '화북남문': 460,
#  '제주동중학교': 461,
#  '삼양초등학교': 555,
#  '원당분화원': 463,
#  '문서교': 647,
#  '조천리': 556,
#  '해양연구소': 643,
#  '함덕비석거리': 467,
#  '함덕농협지소': 468,
#  '함덕리 3구': 469,
#  '함덕환승정류장(함덕해수욕장)': 470,
#  '함덕리(4구)': 471,
#  '911의원': 472,
#  '영등물': 561,
#  '김녕환승정류장(김녕초등학교)': 548,
#  '지경곰': 589,
#  '월정리': 546,
#  '한동리서동': 545,
#  '한동리': 478,
#  '평대리사무소': 641,
#  '평대리동동': 480,
#  '세화리시장2동': 481,
#  '세화환승정류장(세화리)': 482,
#  '세화리구좌농협': 483,
#  '해녀박물관입구': 484,
#  '하도리': 591,
#  '종달리': 543,
#  '종달초등학교': 487,
#  '시흥리': 488,
#  '시흥리사무소': 489,
#  '성산국민체육센터': 490,
#  '성산고입구삼거리': 491,
#  '오조리 입구': 492,
#  '성산고등학교': 493,
#  '성산포 수협': 540,
#  '고성리 구 성산농협': 495,
#  '성산읍사무소': 566,
#  '난산입구': 593,
#  '신산리': 498,
#  '삼달교차로': 568,
#  '신천리취락구조': 539,
#  '신천리': 501,
#  '하천하동': 502,
#  '표선초등학교': 503,
#  '표선환승정류장(표선리 제주은행)': 504,
#  '성산포수협표선지점': 505,
#  '표선오일시장': 506,
#  '그린카센터': 507,
#  '한지동': 538,
#  '가흥동': 509,
#  '세화2리사무소': 510,
#  '가마초등학교': 511,
#  '샤인빌리조트입구': 512,
#  '어촌계입구': 597,
#  '씨사이드홈': 537,
#  '남원읍사무소': 515,
#  '남원포구입구': 516,
#  '남원1리사무소': 517,
#  '동부보건소': 576,
#  '위미3리 마을회관': 605,
#  '위미3리': 520,
#  '대원상동': 604,
#  '뒤통모루': 522,
#  '신례2리교차로': 579,
#  '삼성여자고등학교': 620,
#  '세기아파트': 581,
#  '주공 3 4단지': 526,
#  '동문로터리': 527,
#  '현대산부인과': 528,
#  '청소년문화의집': 529,
#  '구 터미널': 530,
#  '아랑조을거리 입구': 531,
#  '평생학습관': 532,
#  'LH아파트': 602,
#  '서성동': 577,
#  '위미초등학교': 535,
#  '동원산업': 508,
#  '성산리입구': 563,
#  '성산일출봉입구': 541,
#  '오조해녀의집': 494,
#  '하도리면수동': 485,
#  '평대초등학교': 642,
#  '구좌중앙초등학교': 477,
#  '동성동': 475,
#  '김녕리': 549,
#  '조천읍사무소': 607,
#  '대섬입구': 550,
#  '제주버스터미널(가상정류소)': 718,
#  '제주대학교교육대학': 458,
#  '거로 입구': 552,
#  '화북주공아파트': 462,
#  '삼양2동': 554,
#  '신촌초등학교': 465,
#  '조천환승정류장(조천리사무소)': 466,
#  '북촌리해동': 473,
#  '북촌리': 558,
#  '동복리': 585,
#  '동복리관광체험어장': 560,
#  '남흘동': 474,
#  '행원리': 584,
#  '행원농공단지': 562,
#  '계룡동': 479,
#  '성산항입구': 616,
#  '성산리 취락구조': 542,
#  '광치기해변': 564,
#  '성산환승정류장(고성리 한국물류)': 496,
#  '고성리 성산농협': 565,
#  '혼인지입구': 611,
#  '희진주유소': 594,
#  '한지교차로': 569,
#  '토산관광지구입구': 513,
#  '산열이통입구': 570,
#  '수농원': 595,
#  '태흥3리': 613,
#  '태흥초등학교': 514,
#  '광지동': 518,
#  '남원생활체육관': 575,
#  '농협주유소': 578,
#  '창남거리': 525,
#  '비석거리': 580,
#  '광대왓': 534,
#  '하도초등학교': 668,
#  '하도리 서문동': 583,
#  '조천체육관': 557,
#  '주암주택': 586,
#  '동복리휴게소': 609,
#  '김녕해수욕장': 588,
#  '금산목': 590,
#  '하도리동동': 486,
#  '화성농장': 667,
#  '신산환승정류장(성산농협신산지점)': 499,
#  '신흥1번지': 617,
#  '신흥교차로': 572,
#  '태흥3리사무소': 573,
#  '무도동': 574,
#  '종보존연구센터': 521,
#  '위미문화의집': 536,
#  '하례1리입구': 625,
#  '남성마을입구': 533,
#  '서귀포여자고등학교': 630,
#  '고래왓': 582,
#  '만장굴입구': 476,
#  '삼양검문소': 464,
#  '신촌리': 551,
#  '북촌다려마을': 559,
#  '신양리입구': 497,
#  '성산농협종합유통센터': 610,
#  '신풍리하동': 500,
#  '신흥리취락구조': 596,
#  '서소동': 598,
#  '진은동': 614,
#  '상원동': 523,
#  '효돈농협하나로마트': 618,
#  '신성동': 606,
#  '송천교': 571,
#  '세천동': 599,
#  '맹살공원': 635,
#  '상효입구': 662,
#  '토평 보목입구': 619,
#  '남원취락구조': 519,
#  '충혼묘지': 587,
#  '조천초등학교': 646,
#  '하천리취락구조': 621,
#  '표선환승정류장(표선리사무소)': 622,
#  '위미1리사무소': 637,
#  '망장포 입구': 636,
#  '서귀포버스터미널(가상정류소)': 663,
#  '수모루': 629,
#  '여 의 물': 631,
#  '삼매봉': 632,
#  '서귀포시 구 버스터미널': 633,
#  '매일올레시장 7번입구': 627,
#  '삼아아파트': 634,
#  '효돈축구공원': 615,
#  '공천포': 524,
#  '대화동': 624,
#  '표선파출소': 623,
#  '온평초등학교': 567,
#  '성산환승정류장(고성리 회전교차로)': 658,
#  '고성리제주은행': 638,
#  '금붕사': 640,
#  '함덕리 4구': 657,
#  '조천만세동산': 644,
#  '조천환승정류장(조천우체국)': 645,
#  '삼양동주민센터': 666,
#  '국립제주박물관': 648,
#  '우당도서관': 649,
#  '사라봉': 650,
#  '사라봉오거리': 651,
#  '제주여자상업고등학교': 652,
#  '제일교 동문시장입구': 653,
#  '동문성당': 654,
#  '신산로': 655,
#  '성산리': 639,
#  '농협 하나로마트': 660,
#  '오조리': 661,
#  '월정리 용천동': 547,
#  '서귀포동부도서관': 717,
#  '대륜동주민센터': 628,
#  '폭낭사거리': 659,
#  '온평리': 676,
#  '진드르': 608,
#  '하도리창흥동': 592,
#  '원당봉': 665,
#  '보목입구': 626,
#  '고망난돌입구': 612,
#  '난산입구(성산기상대)': 664,
#  '효돈중학교': 673,
#  '효돈초등학교': 669,
#  '신협': 670,
#  '신효동': 671,
#  '월라봉': 672,
#  '평대리서동': 544,
#  '앞동산': 675,
#  '신효': 674,
#  '구좌보건지소': 678,
#  '삼매봉입구': 601,
#  '세화고등학교': 680,
#  '상도마을회관': 715,
#  '오조리상동입구': 683,
#  '고성오일시장': 681,
#  '오조리하동': 682,
#  '사회복지법인 춘강': 684,
#  '산천단': 685,
#  '제주국제대학교': 694,
#  '입석동': 703,
#  '하례환승정류장(하례리입구)': 688,
#  '평안전문요양원': 699,
#  '뒷빌레': 690,
#  '토평마을회관': 691,
#  '답다니': 702,
#  '영천동주민센터': 692,
#  '양지(추모)공원': 687,
#  '제주의료원': 686,
#  '종합사격장': 695,
#  '견월교': 709,
#  '교래입구': 696,
#  '서귀포산업과학고등학교': 689,
#  '공업단지 입구': 705,
#  '오희준 공원': 700,
#  '흙통': 701,
#  '중앙로터리': 693,
#  '제주컨트리클럽': 707,
#  '성판악': 697,
#  '수악교': 704,
#  '고도농원': 713,
#  '한라생태숲': 708,
#  '마방목지': 706,
#  '꽃동산': 710,
#  '법호촌입구': 712,
#  '법호촌 온성학교': 698,
#  '산천단 한국폴리텍대학': 711,
#  '한라산 둘레길': 714,
#  '효례교': 600,
#  '상도리 세화고등학교': 677,
#  '전경대 입구': 716,
#  '하도리 개긋물': 679,
#  '제주한라대학교(종점)': 443,
#  '서귀포버스터미널': 603,
#  '제주버스터미널(종점)': 656}

# %% [markdown]
# ### 범주형 -> 수치형 자료로 변환

# %%
train[['route_nm', 'now_station', 'next_station']] = train[['route_nm', 'now_station', 'next_station']].applymap(lambda x : my_dict[x])
train.head()
# Out:
#    id        date   route_id    vh_id  route_nm  now_latitude  now_longitude  \
# 0   0  2019-10-15  405136001  7997025         0     33.456267     126.551750
# 1   1  2019-10-15  405136001  7997025         0     33.457724     126.554014
# 2   2  2019-10-15  405136001  7997025         0     33.458783     126.557353
# 3   3  2019-10-15  405136001  7997025         0     33.479705     126.543811
# 4   4  2019-10-15  405136001  7997025         0     33.485662     126.494923
#
#    now_station now_arrive_time  distance  next_station  next_latitude  \
# 0          400             06시     266.0           369      33.457724
# 1          369             06시     333.0           370      33.458783
# 2          370             06시     415.0           371      33.459893
# 3          403             06시     578.0           372      33.484860
# 4          382             07시     374.0           373      33.485822
#
#    next_longitude  next_arrive_time
# 0      126.554014                24
# 1      126.557353                36
# 2      126.561624                40
# 3      126.542928                42
# 4      126.490897                64

# %% [markdown]
# ### 시간 데이터 타입 변환

# %%
# 시간 데이터 타입 변환 함수
def text_to_time(text:str):
    return int(text[:2])

train['now_arrive_time'] = train['now_arrive_time'].map(text_to_time)
train.head()
# Out:
#    id        date   route_id    vh_id  route_nm  now_latitude  now_longitude  \
# 0   0  2019-10-15  405136001  7997025         0     33.456267     126.551750
# 1   1  2019-10-15  405136001  7997025         0     33.457724     126.554014
# 2   2  2019-10-15  405136001  7997025         0     33.458783     126.557353
# 3   3  2019-10-15  405136001  7997025         0     33.479705     126.543811
# 4   4  2019-10-15  405136001  7997025         0     33.485662     126.494923
#
#    now_station  now_arrive_time  distance  next_station  next_latitude  \
# 0          400                6     266.0           369      33.457724
# 1          369                6     333.0           370      33.458783
# 2          370                6     415.0           371      33.459893
# 3          403                6     578.0           372      33.484860
# 4          382                7     374.0           373      33.485822
#
#    next_longitude  next_arrive_time
# 0      126.554014                24
# 1      126.557353                36
# 2      126.561624                40
# 3      126.542928                42
# 4      126.490897                64

# %%
# train['now_arrive_time'].map(text_to_time)

# %%
train['now_arrive_time'][:2]
# Out:
# 0    6
# 1    6
# Name: now_arrive_time, dtype: int64

# %%
# train['now_arrive_time'].map(text_to_time)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210457 entries, 0 to 210456
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                210457 non-null  int64
#  1   date              210457 non-null  object
#  2   route_id          210457 non-null  int64
#  3   vh_id             210457 non-null  int64
#  4   route_nm          210457 non-null  int64
#  5   now_latitude      210457 non-null  float64
#  6   now_longitude     210457 non-null  float64
#  7   now_station       210457 non-null  int64
#  8   now_arrive_time   210457 non-null  int64
#  9   distance          210457 non-null  float64
#  10  next_station      210457 non-null  int64
#  11  next_latitude     210457 non-null  float64
#  12  next_longitude    210457 non-null  float64
#  13  next_arrive_time  210457 non-null  int64
# dtypes: float64(5), int64(8), object(1)
# memory usage: 22.5+ MB

# %% [markdown]
# ### test 데이터 셋 적용

# %%
def transform_df(df:pd.DataFrame):
  
    df[['route_nm', 'now_station', 'next_station']] = df[['route_nm', 'now_station', 'next_station']].applymap(lambda x:my_dict[x])

    def text_to_time(text:str):
        return int(text[:2])

    df['now_arrive_time'] = df['now_arrive_time'].map(text_to_time)
    return df

test = transform_df(test)
test
# Out:
#            id        date   route_id    vh_id  route_nm  now_latitude  \
# 0      210457  2019-10-29  405136001  7997025         0     33.457724
# 1      210458  2019-10-29  405136001  7997025         0     33.458783
# 2      210459  2019-10-29  405136001  7997025         0     33.478867
# 3      210460  2019-10-29  405136001  7997025         0     33.478850
# 4      210461  2019-10-29  405136001  7997025         0     33.480700
# ...       ...         ...        ...      ...       ...           ...
# 91769  302350  2019-11-05  405328102  7983486        20     33.493625
# 91770  302351  2019-11-05  405328102  7983486        20     33.495540
# 91771  302352  2019-11-05  405328102  7983486        20     33.498925
# 91772  302353  2019-11-05  405328102  7983486        20     33.500473
# 91773  302354  2019-11-05  405328102  7983486        20     33.499916
#
#        now_longitude  now_station  now_arrive_time  distance  next_station  \
# 0         126.554014          369                7     333.0           370
# 1         126.557353          370                7     415.0           371
# 2         126.483833          408                8     417.0           374
# 3         126.488350          374                8     334.0           375
# 4         126.489933          375                8     550.0           401
# ...              ...          ...              ...       ...           ...
# 91769     126.534764          410               20     272.0           409
# 91770     126.532907          409               20     447.0           414
# 91771     126.530351          414               20     418.0           418
# 91772     126.527103          418               20     140.0           391
# 91773     126.521348          420               20     541.0           656
#
#        next_latitude  next_longitude
# 0          33.458783      126.557353
# 1          33.459893      126.561624
# 2          33.478850      126.488350
# 3          33.480700      126.489933
# 4          33.482077      126.485355
# ...              ...             ...
# 91769      33.495540      126.532907
# 91770      33.498925      126.530351
# 91771      33.500473      126.527103
# 91772      33.500228      126.525625
# 91773      33.499190      126.516324
#
# [91774 rows x 13 columns]

# %% [markdown]
# ### 종속변수 설정

# %%
y = train['next_arrive_time']

y.head()
# Out:
# 0    24
# 1    36
# 2    40
# 3    42
# 4    64
# Name: next_arrive_time, dtype: int64

# %% [markdown]
# ### 독립변수 설정

# %%
features = ['route_id', 'vh_id',  'route_nm', 'now_latitude', 'now_longitude', 'now_station', 'now_arrive_time', 'distance', 'next_station', 'next_latitude', 'next_longitude']
X = train[features]
X.head()
# Out:
#     route_id    vh_id  route_nm  now_latitude  now_longitude  now_station  \
# 0  405136001  7997025         0     33.456267     126.551750          400
# 1  405136001  7997025         0     33.457724     126.554014          369
# 2  405136001  7997025         0     33.458783     126.557353          370
# 3  405136001  7997025         0     33.479705     126.543811          403
# 4  405136001  7997025         0     33.485662     126.494923          382
#
#    now_arrive_time  distance  next_station  next_latitude  next_longitude
# 0                6     266.0           369      33.457724      126.554014
# 1                6     333.0           370      33.458783      126.557353
# 2                6     415.0           371      33.459893      126.561624
# 3                6     578.0           372      33.484860      126.542928
# 4                7     374.0           373      33.485822      126.490897

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.3, random_state=111)

# %% [markdown]
# ### 모델 선택

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %% [markdown]
# ### 모델 학습

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 모델 예측

# %%
pred = model.predict(X_val)

# %% [markdown]
# ### 검증

# %%
from sklearn.metrics import r2_score

r2_score(y_val, pred)
# Out:
# 0.23308739342251805

# %% [markdown]
# ### 데이터 시각화해보기

# %%
# 파이썬 warning 무시
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# 시각화를 위한 라이브러리
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트를 사용하기 위한 코드
fe = fm.FontEntry(fname = 'NotoSansKR-Regular.otf', name = 'NotoSansKR')
fm.fontManager.ttflist.insert(0, fe)
plt.rc('font', family='NotoSansKR')

## 코드 작성          
train['next_arrive_time'].plot(figsize=(20,10), alpha=0.4)

plt.title('버스 운행시간')
plt.xlabel('인덱스')
plt.ylabel('운행시간')

plt.show()
# Out:
# findfont: Font family ['NotoSansKR'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['NotoSansKR'] not found. Falling back to DejaVu Sans.
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family ['NotoSansKR'] not found. Falling back to DejaVu Sans.
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45937 (\N{HANGUL SYLLABLE DEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
train['next_arrive_time'].plot(figsize=(20,10), alpha=0.4)    

plt.title('버스 운행시간')    
plt.xlabel('인덱스')    
plt.ylabel('운행시간')    

plt.hlines(y = 20, xmin=0, xmax=len(train), colors='red')    
plt.hlines(y = 250, xmin=0, xmax=len(train), colors='red')    
plt.hlines(y = 600, xmin=0, xmax=len(train), colors='blue')    
plt.hlines(y = 2300, xmin=0, xmax=len(train), colors='green')    

plt.show()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45937 (\N{HANGUL SYLLABLE DEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### 버스 운행 시간 구간별 데이터셋

# %%
a = train[train['next_arrive_time']<20]
b = train[(train['next_arrive_time']>=20) & (train['next_arrive_time']<250)]
c = train[(train['next_arrive_time']>=250) & (train['next_arrive_time']<600)]
d = train[(train['next_arrive_time']>=600) & (train['next_arrive_time']<2300)]
e = train[(train['next_arrive_time']>=2300)]

# %% [markdown]
# ### 버스 운행 시간 구간별 횟수 시각화

# %%
# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
lst1 = [len(a), len(b), len(c), len(d), len(e)]
plt.bar(['20미만', '20~250', '250~600', '600~2300', '2300이상'], lst1)
plt.show()

# %%
x = ['20미만', '20~250', '250~600', '600~2300', '2300이상']
y = [len(a),len(b),len(c),len(d),len(e)]

plt.figure(dpi=150)

plt.title('버스 운행시간 구간 별 횟수')
plt.xlabel('버스 운행시간 구간')
plt.ylabel('횟수')

plt.bar(x,y)
plt.show()

# %%
x = ['b구간', '나머지']
y = [len(b)/len(train), (1-len(b)/len(train))]

plt.figure(dpi=150)

plt.title('버스 운행시간 구간 비율')

plt.pie(y, labels=x)
plt.legend()
plt.show()

# %%
plt.figure(dpi=150)

plt.title('버스 운행시간 히스토그램')
plt.xlabel('운행시간')
plt.ylabel('횟수')

plt.hist(train[train['next_arrive_time']<600]['next_arrive_time'], bins=20)
plt.show()

# %%
x = ['운행시간<20', '운행시간>=20']
y = [a['distance'].mean(), pd.concat([b,c,d,e])['distance'].mean()]

plt.figure(dpi=150)

plt.title('운행시간 vs 거리')
plt.xlabel('운행시간')
plt.ylabel('거리')

plt.bar(x,y)
plt.show()

# %%
x = ['20~250', '250~600']
y = [b['distance'].mean(), c['distance'].mean()]

plt.figure(dpi=150)

plt.title('운행시간 vs 거리')
plt.xlabel('운행시간')
plt.ylabel('거리')

plt.bar(x,y)
plt.show()

# %%
import matplotlib.patches as patches

x = train['distance']
y = train['next_arrive_time']

plt.figure(dpi = 150)

plt.title('거리 vs 운행시간')
plt.xlabel('거리')
plt.ylabel('운행시간')

plt.scatter(x,y, alpha = 0.3)

plt.show()

# %%
import matplotlib.patches as patches

x = train['distance']
y = train['next_arrive_time']

plt.figure(dpi = 150)

plt.title('거리 vs 운행시간')
plt.xlabel('거리')
plt.ylabel('운행시간')

plt.scatter(x,y, alpha = 0.3)

# 이상치 표시하기 - 직사각형
plt.gca().add_patch(
    patches.Rectangle(
        (0, 600),
        1000, 2600,               
        edgecolor = 'deeppink',
        fill=False,
    ))

plt.show()

# %% [markdown]
# ### 지도에서 이상치 표현

# %%
import folium

locations = train[(train['distance'] <= 1000) & (train['next_arrive_time'] >= 600)][['next_latitude', 'next_longitude']].values.tolist()

center = [((train[['now_latitude', 'now_longitude']].loc[1].values[0])+(train[['now_latitude', 'now_longitude']].loc[len(train)-1].values[0]))/2, 
          ((train[['now_latitude', 'now_longitude']].loc[1].values[1])+(train[['now_latitude', 'now_longitude']].loc[len(train)-1].values[1]))/2]
          
m = folium.Map(location=center, zoom_start=11, tiles='cartodbpositron')

for location in locations:
    folium.Circle(
        radius=300,
        location=location,
        fill=True
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2bba4219eadc1776d71a4b08677022dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2bba4219eadc1776d71a4b08677022dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2bba4219eadc1776d71a4b08677022dd = L.map(
#                 &quot;map_2bba4219eadc1776d71a4b08677022dd&quot;,
#                 {
#                     center: [33.3531055, 126.53260449999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bfc0b2fdf7ae3dbc54e7dc1ed50c4aec = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2bba4219eadc1776d71a4b08677022dd);
#
#
#             var circle_26f2057e48f17a1590719a8023c1b699 = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2bba4219eadc1776d71a4b08677022dd);
#
#
#             var circle_13a66626e7ef152af502fbdfacd8bd1c = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2bba4219eadc1776d71a4b08677022dd);
#
#
#             var circle_b425a37e1bc5547f1dc4240275953584 = L.circle(
#                 [33.47626, 126.481417],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2bba4219eadc1776d71a4b08677022dd);
#
#
#             var circle_b202805e306ace44fda80993d54907dc = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2bba4219eadc1776d71a4b08677022dd);
#
#
#             var circle_c2d2e69d422c5667c98b497ec15666f0 = L.circle(
#                 [33.47626, 126.481417],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2bba4219eadc1776d71a4b08677022dd);
#
#
#             var circle_b210b6a360e1c18d55dd23252d9b992f = L.circle(
#                 [33.47626, 126.481417],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;

# %%
temp = train[(train['distance'] >= 1000) | (train['next_arrive_time'] <= 600)]

x = temp['distance']
y = temp['next_arrive_time']

plt.figure(dpi = 150)
plt.scatter(x,y, alpha = 0.3)

# 운행시간 분포 표시하기 - 타원
plt.gca().add_patch(
   patches.Ellipse(
      (4000, 600),
      8000, 800,               
      edgecolor = 'deeppink',
      fill=False,
      angle=3
   ))

# %%
# 운행 시간이 2300 이상인 데이터의 좌표 정보 (list)
locations = train[train['next_arrive_time'] >= 2300][['next_latitude', 'next_longitude']].values.tolist()

# 지도 중심 좌표
center = [((train[['now_latitude', 'now_longitude']].loc[1].values[0])+(train[['now_latitude', 'now_longitude']].loc[len(train)-1].values[0]))/2, 
          ((train[['now_latitude', 'now_longitude']].loc[1].values[1])+(train[['now_latitude', 'now_longitude']].loc[len(train)-1].values[1]))/2]

# 지도 그리기
m = folium.Map(location=center, zoom_start=11)

# 점(Circle) 표시하기
for location in locations:
    folium.Circle(
        radius=300,
        location=location,
        fill=True
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f3acd54d85e9b4ecbae525961b6341c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f3acd54d85e9b4ecbae525961b6341c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f3acd54d85e9b4ecbae525961b6341c = L.map(
#                 &quot;map_7f3acd54d85e9b4ecbae525961b6341c&quot;,
#                 {
#                     center: [33.3531055, 126.53260449999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_700b0282b327038f9ae86b900ff94569 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7f3acd54d85e9b4ecbae525961b6341c);
#
#
#             var circle_0c8732266d97b68f5f00265ad1380dca = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7f3acd54d85e9b4ecbae525961b6341c);
#
#
#             var circle_2802f4cad208c68dee21affc6eb51f2f = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7f3acd54d85e9b4ecbae525961b6341c);
#
#
#             var circle_c56b2f37dd5a9f7187e03bb4b7f70441 = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7f3acd54d85e9b4ecbae525961b6341c);
#
#
#             var circle_bc802daf2ce93755bcce0bda1fcaa9ac = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7f3acd54d85e9b4ecbae525961b6341c);
#
#
#             var circle_8d2ba34ed4e6bd9b1a3e0d6f2ba74d84 = L.circle(
#                 [33.4589, 126.5573],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7f3acd54d85e9b4ecbae525961b6341c);
#
#
#             var circle_11199665601524c0bec5345d7e9b22fe = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7f3acd54d85e9b4ecbae525961b6341c);
#
#
#             var circle_eb35e331606274a07360724f14aa2e64 = L.circle(

# %%
train[(train['next_station'] == '제주대학교') & (train['next_arrive_time'] >= 2300)]
# Out:
#             id        date   route_id    vh_id route_nm  now_latitude  \
# 2003      2003  2019-10-15  405136002  7997082    360-2     33.458900
# 3487      3487  2019-10-15  405136521  7997070   365-21     33.458900
# 19236    19236  2019-10-16  405136521  7997001   365-21     33.458900
# 19864    19864  2019-10-16  405136521  7997087   365-21     33.458900
# 34763    34763  2019-10-17  405136521  7997070   365-21     33.458900
# 50606    50606  2019-10-18  405136521  7997001   365-21     33.458900
# 51100    51100  2019-10-18  405136521  7997087   365-21     33.458900
# 80094    80094  2019-10-20  405136521  7997001   365-21     33.458900
# 95465    95465  2019-10-21  405136521  7997089   365-21     33.458900
# 110341  110341  2019-10-22  405136012  7997033   360-12     33.458900
# 110733  110733  2019-10-22  405136521  7997031   365-21     33.458900
# 125381  125381  2019-10-23  405136012  7997033   360-12     33.458900
# 139754  139754  2019-10-24  405136002  7997043    360-2     33.458900
# 140101  140101  2019-10-24  405136002  7997111    360-2     33.458900
# 141694  141694  2019-10-24  405136521  7997087   365-21     33.458900
# 170888  170888  2019-10-26  405136521  7997001   365-21     33.458900
# 201187  201187  2019-10-28  405136522  7997107   365-22     33.458783
#
#         now_longitude now_station now_arrive_time  distance next_station  \
# 2003       126.557300       제대아파트             17시     435.0        제주대학교
# 3487       126.557300       제대아파트             16시     435.0        제주대학교
# 19236      126.557300       제대아파트             18시     435.0        제주대학교
# 19864      126.557300       제대아파트             18시     435.0        제주대학교
# 34763      126.557300       제대아파트             17시     435.0        제주대학교
# 50606      126.557300       제대아파트             18시     435.0        제주대학교
# 51100      126.557300       제대아파트             13시     435.0        제주대학교
# 80094      126.557300       제대아파트             21시     435.0        제주대학교
# 95465      126.557300       제대아파트             16시     435.0        제주대학교
# 110341     126.557300       제대아파트             17시     435.0        제주대학교
# 110733     126.557300       제대아파트             07시     435.0        제주대학교
# 125381     126.557300       제대아파트             07시     435.0        제주대학교
# 139754     126.557300       제대아파트             09시     435.0        제주대학교
# 140101     126.557300       제대아파트             18시     435.0        제주대학교
# 141694     126.557300       제대아파트             18시     435.0        제주대학교
# 170888     126.557300       제대아파트             21시     435.0        제주대학교
# 201187     126.557353       제대아파트             18시     415.0        제주대학교
#
#         next_latitude  next_longitude  next_arrive_time
# 2003        33.460114      126.561659              2906
# 3487        33.460114      126.561659              2472
# 19236       33.460114      126.561659              2652
# 19864       33.460114      126.561659              2856
# 34763       33.460114      126.561659              2556
# 50606       33.460114      126.561659              2670
# 51100       33.460114      126.561659              2722
# 80094       33.460114      126.561659              2582
# 95465       33.460114      126.561659              2870
# 110341      33.460114      126.561659              2780
# 110733      33.460114      126.561659              2930
# 125381      33.460114      126.561659              2812
# 139754      33.460114      126.561659              2614
# 140101      33.460114      126.561659              2538
# 141694      33.460114      126.561659              2770
# 170888      33.460114      126.561659              2336
# 201187      33.459893      126.561624              2874

# %%
train[(train['next_station'] == '제주대학교') & (train['next_arrive_time'] > 2300)][['next_latitude', 'next_longitude']].iloc[0].values.tolist()
# Out:
# [33.460114000000004, 126.561659]

# %%
train[(train['next_station'] == '제주대학교') & (train['next_arrive_time'] > 2300)][['next_latitude', 'next_longitude']].iloc[0].values
# Out:
# array([ 33.460114, 126.561659])

# %%
#제주대학교 좌표
locations = [train[(train['next_station'] == '제주대학교')][['next_latitude', 'next_longitude']].iloc[0].values.tolist(),
             train[(train['next_station'] == '제주대학교') & (train['next_arrive_time'] > 2300)][['next_latitude', 'next_longitude']].iloc[0].values.tolist()]

# 지도 중심 좌표
center = [((train[['now_latitude', 'now_longitude']].loc[1].values[0])+(train[['now_latitude', 'now_longitude']].loc[len(train)-1].values[0]))/2, 
          ((train[['now_latitude', 'now_longitude']].loc[1].values[1])+(train[['now_latitude', 'now_longitude']].loc[len(train)-1].values[1]))/2]

# 지도 그리기
m = folium.Map(location=center, zoom_start=11, tiles='cartodbpositron')

# 점 찍기
for i, location in enumerate(locations):
    folium.Circle(
        radius=10,
        location=location,
        tooltip=i,
        fill=True
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f56daf25b18619cc6b22d7e7a752d1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f56daf25b18619cc6b22d7e7a752d1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f56daf25b18619cc6b22d7e7a752d1a = L.map(
#                 &quot;map_1f56daf25b18619cc6b22d7e7a752d1a&quot;,
#                 {
#                     center: [33.3531055, 126.53260449999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bfddb1c8a60549a1ca5fb8c1fc4cabf6 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1f56daf25b18619cc6b22d7e7a752d1a);
#
#
#             var circle_25c501da45744d9d51f9d56ae158f37f = L.circle(
#                 [33.459893, 126.561624],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1f56daf25b18619cc6b22d7e7a752d1a);
#
#
#             circle_25c501da45744d9d51f9d56ae158f37f.bindTooltip(
#                 `&lt;div&gt;
#                      0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_e012e136e25fc0b74f7fa562e91ed4b0 = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1f56daf25b18619cc6b22d7e7a752d1a);
#
#
#             circle_e012e136e25fc0b74f7fa562e91ed4b0.bindTooltip(
#                 `&lt;div&gt;
#                      1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 운행 시간이 긴 데이터
X = train[train['next_longitude'] == 126.561659]['next_arrive_time'].reset_index(drop=True).index
Y = train[train['next_longitude'] == 126.561659]['next_arrive_time'].reset_index(drop=True).values

plt.plot(X,Y)
plt.show()

# %%
# 데이터 전처리 함수
def transform_df(df:pd.DataFrame):

    # my_dict 적용
    df[['route_nm', 'now_station', 'next_station']] = df[['route_nm', 'now_station', 'next_station']].applymap(lambda x:my_dict[x])

    # 시간 정보 str -> int 데이터 타입 변환 함수
    def text_to_time(text:str):
        return int(text[:2])

    # 시간 데이터 타입 변환 함수 적용
    df['now_arrive_time'] = df['now_arrive_time'].map(text_to_time)
  
    return df
 
train = transform_df(train)
test = transform_df(test)

# %%
# 이상치 실습
train = train[train['next_arrive_time'] <= 1000]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 210257 entries, 0 to 210456
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                210257 non-null  int64
#  1   date              210257 non-null  object
#  2   route_id          210257 non-null  int64
#  3   vh_id             210257 non-null  int64
#  4   route_nm          210257 non-null  int64
#  5   now_latitude      210257 non-null  float64
#  6   now_longitude     210257 non-null  float64
#  7   now_station       210257 non-null  int64
#  8   now_arrive_time   210257 non-null  int64
#  9   distance          210257 non-null  float64
#  10  next_station      210257 non-null  int64
#  11  next_latitude     210257 non-null  float64
#  12  next_longitude    210257 non-null  float64
#  13  next_arrive_time  210257 non-null  int64
# dtypes: float64(5), int64(8), object(1)
# memory usage: 24.1+ MB

# %%
features = train.columns[2:-1]     
target = train.columns[-1]    

X = train[features]     
y = train[target]

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X,y, test_size=0.1, shuffle=False)

#데이터 shape 확인
print(f"X_train.shape : {X_train.shape}")
print(f"y_train.shape : {y_train.shape}")
print(f"X_valid.shape : {X_valid.shape}")
print(f"y_valid.shape : {y_valid.shape}")
# Out:
# X_train.shape : (189231, 11)
# y_train.shape : (189231,)
# X_valid.shape : (21026, 11)
# y_valid.shape : (21026,)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
pred = model.predict(X_valid)

# %%
# 학습된 모델을 이용해 결괏값 예측 후 상위 10개의 값 확인
predict = model.predict(test[features])
print('----------------------예측된 데이터의 상위 10개의 값 확인--------------------\n')
print(predict[:10])
# Out:
# ----------------------예측된 데이터의 상위 10개의 값 확인--------------------
#
# [ 33.29983333  43.87916667 134.67701587  60.47752381 172.45316667
#   28.04971429  72.90690476 203.95104762 130.37157143 117.64061905]

# %%
submission['next_arrive_time'] = predict     
submission.head()
# Out:
#        id  next_arrive_time
# 0  210457         33.299833
# 1  210458         43.879167
# 2  210459        134.677016
# 3  210460         60.477524
# 4  210461        172.453167

# %%
# 검증
from sklearn.metrics import r2_score

r2_score(y_valid, pred)
# Out:
# 0.7059877140412798

# %%
submission.to_csv('submission.csv', index=False)
